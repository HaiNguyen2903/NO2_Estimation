# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import LinearRegression

import numpy as np
from sklearn.model_selection import KFold

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import os
import math
import pickle

# %%
# Mouting with google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Config path and variable

# %%
# Path to data folder
data_folder = '/content/drive/MyDrive/STUDYING/HK2 2020-2021/Modern Problems in Technology/'

# Choose one of 2 versions below:
# Uncomment below line to choose scaled data version
# data_version = 'data_processed_withscale.csv'|

# Uncomment below line to choose non-scaled data version
data_version = 'data_processed_withscale_full_features.csv'

# %% [markdown]
# ## Reading data version

# %%
data = pd.read_csv(os.path.join(data_folder, data_version))

data
# Out:
#       time       lat       lon  ...  pplt_dens road_dens  cluster
# 0       11  0.945033  0.181002  ...   0.062616  0.204322        3
# 1       12  0.945033  0.181002  ...   0.062616  0.204322        3
# 2       13  0.945033  0.181002  ...   0.062616  0.204322        3
# 3       14  0.945033  0.181002  ...   0.062616  0.204322        3
# 4       15  0.945033  0.181002  ...   0.062616  0.204322        3
# ...    ...       ...       ...  ...        ...       ...      ...
# 5455  1227  0.939449  0.156999  ...   1.000000  0.793592        0
# 5456  1228  0.939449  0.156999  ...   1.000000  0.793592        0
# 5457  1229  0.939449  0.156999  ...   1.000000  0.793592        0
# 5458  1230  0.939449  0.156999  ...   1.000000  0.793592        0
# 5459  1231  0.939449  0.156999  ...   1.000000  0.793592        0
#
# [5460 rows x 18 columns]

# %%
# data = data[data.cluster != 2]
# Unique cluster value
data['cluster'].unique()
# Out:
# array([3, 2, 1, 0])

# %% [markdown]
# ## Remove Invalid NO2 values

# %%
# Run this if you want to remove invalid no2 values

data = data[(data.NO2 > 0) & (data.NO2 < 100)]
data[data.NO2 > 100]
# Out:
# Empty DataFrame
# Columns: [time, lat, lon, NO2, name, pblh, press, rh, tmp, wspd, dpt_00, dpt_06, dpt_12, dpt_18, ndvi, pplt_dens, road_dens, cluster]
# Index: []

# %% [markdown]
# ## Drop useless columns

# %%
def drop_cols(df):
  drops = ['lat', 'lon', 'cluster', 'dpt_00', 'dpt_06', 'dpt_12', 'dpt_18']
  for col in drops:
    if col in df:
      df.drop(col, axis='columns', inplace=True)

# drop_cols(data)

# %% [markdown]
# ## Convert to numpy for feeding model

# %%
X = data.drop(['NO2', 'name'], axis = 'columns')
X_arr = X.to_numpy()

y = data['NO2']
y_arr = y.to_numpy()

print(X.shape, y.shape)
# Out:
# (4679, 16) (4679,)

# %%
# X_train = X.drop(['dpt_00', 'dpt_06', 'dpt_12', 'dpt_18'], axis='columns')

# %%
# # X_train = X_train.drop(['lat','lon','cluster'], axis='columns')
# X_train.shape

# %%
# List of RMSE on all folds
# rmses_rf = []
# mapes_rf = []
# r2s_rf = []

# rmses_lr = []
# mapes_lr = []
# r2s_lr = []

# Depth of Random Forest
depth = 200
# Number of split
split_number = 10

map_depth_rmse = {}
map_depth_r2 = {}
map_depth_mape = {}

best_curr_rmse = 1000

model_checkpoint = '/content/drive/MyDrive/STUDYING/HK2 2020-2021/Modern Problems in Technology/best_rf_cua_Giang.pkl'

# How many number want to round with loss (1.424 if precision =3 for example)
precision = 5

def get_key(dict, val):
  for key, value in dict.items():
        if val == value:
            return key

  return "key doesn't exist"

def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape

# KFold for each depth
for d in range(100, depth):
  kf = KFold(n_splits=split_number, random_state=None, shuffle=True)
  kf.get_n_splits(X)

  rmses_rf = []
  mapes_rf = []
  r2s_rf = []

  for train_index, test_index in kf.split(X):
    # print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X_arr[train_index], X_arr[test_index]
    y_train, y_test = y_arr[train_index], y_arr[test_index]
    # print(len(train_index), len(test_index))

    # print('Fold {}:'.format(i))
    rf = RandomForestRegressor(n_estimators = d, random_state = 20)
    rf.fit(X_train, y_train)
    rf_predicts = rf.predict(X_test)
    # Calculate RMSE
    rmse_rf = math.sqrt(mean_squared_error(y_test, rf_predicts))
    # Calculate R2 Score
    r2_rf = r2_score(y_test, rf_predicts)
    # Calculate mean absolute error (MAE NOT MAPE)
    # mape_rf = mean_absolute_error(y_test, rf_predicts)
    mape_rf = MAPE(y_test, rf_predicts)

    # With each depth, calculate and save losses of all fold
    rmses_rf.append(rmse_rf)
    r2s_rf.append(r2_rf)
    mapes_rf.append(mape_rf)

  # After each depth, save average loss to find best depth
  average_rmse_rf = round(np.average(rmses_rf), precision)
  average_r2_rf = round(np.average(r2s_rf), precision)
  average_mape_rf = round(np.average(mapes_rf), precision)

  if average_rmse_rf < best_curr_rmse:
    best_curr_rmse = average_rmse_rf
  
    with open(model_checkpoint, 'wb') as file:  
      pickle.dump(rf, file)

  map_depth_rmse[d] = average_rmse_rf
  map_depth_r2[d] = average_r2_rf
  map_depth_mape[d] = average_mape_rf
  
  print('Depth =', d)
  print('Average RMSE on all folds using Random Forest:', average_rmse_rf)
  print('Average R2 on all folds using Random Forest:', average_r2_rf)
  print('Average MAPE on all folds using Random Forest: {}'.format(average_mape_rf))
  # print('Average MAPE on all folds using Random Forest:', np.average(mapes_rf))
  print()

min_rmse = min(map_depth_rmse.values())
max_r2 = max(map_depth_r2.values())
min_mape = min(map_depth_mape.values())

print('Best depth for RMSE is {} with RMSE = {}'.format(get_key(map_depth_rmse, min_rmse), min_rmse))
print('Best depth for R2 is {} with R2 = {}'.format(get_key(map_depth_r2, max_r2), max_r2))
print('Best depth for R2 is {} with MAPE = {}'.format(get_key(map_depth_mape, min_mape), min_mape))
# Out:
# Depth = 100
# Average RMSE on all folds using Random Forest: 8.42087
# Average R2 on all folds using Random Forest: 0.68742
# Average MAPE on all folds using Random Forest: 35.86036
#
# Depth = 101
# Average RMSE on all folds using Random Forest: 8.40529
# Average R2 on all folds using Random Forest: 0.68853
# Average MAPE on all folds using Random Forest: 35.48054
#
# Depth = 102
# Average RMSE on all folds using Random Forest: 8.41385
# Average R2 on all folds using Random Forest: 0.68751
# Average MAPE on all folds using Random Forest: 35.29114
#
# Depth = 103
# Average RMSE on all folds using Random Forest: 8.36263
# Average R2 on all folds using Random Forest: 0.69153
# Average MAPE on all folds using Random Forest: 35.4316
#
# Depth = 104
# Average RMSE on all folds using Random Forest: 8.42387
# Average R2 on all folds using Random Forest: 0.68726
# Average MAPE on all folds using Random Forest: 35.5283
#
# Depth = 105
# Average RMSE on all folds using Random Forest: 8.35967
# Average R2 on all folds using Random Forest: 0.69174
# Average MAPE on all folds using Random Forest: 35.72932
#
# Depth = 106
# Average RMSE on all folds using Random Forest: 8.32989
# Average R2 on all folds using Random Forest: 0.69408
# Average MAPE on all folds using Random Forest: 35.36932
#
# Depth = 107
# Average RMSE on all folds using Random Forest: 8.4202
# Average R2 on all folds using Random Forest: 0.68756
# Average MAPE on all folds using Random Forest: 35.57254
#
# Depth = 108
# Average RMSE on all folds using Random Forest: 8.38464
# Average R2 on all folds using Random Forest: 0.69037
# Average MAPE on all folds using Random Forest: 35.58278
#
# Depth = 109
# Average RMSE on all folds using Random Forest: 8.35443
# Average R2 on all folds using Random Forest: 0.6916
# Average MAPE on all folds using Random Forest: 35.279
#
# Depth = 110
# Average RMSE on all folds using Random Forest: 8.40663
# Average R2 on all folds using Random Forest: 0.68892
# Average MAPE on all folds using Random Forest: 35.8001
#
# Depth = 111
# Average RMSE on all folds using Random Forest: 8.36255
# Average R2 on all folds using Random Forest: 0.69083
# Average MAPE on all folds using Random Forest: 35.53499
#
# Depth = 112
# Average RMSE on all folds using Random Forest: 8.36515
# Average R2 on all folds using Random Forest: 0.69164
# Average MAPE on all folds using Random Forest: 35.354
#
# Depth = 113
# Average RMSE on all folds using Random Forest: 8.36726
# Average R2 on all folds using Random Forest: 0.69104
# Average MAPE on all folds using Random Forest: 35.40431
#
# Depth = 114
# Average RMSE on all folds using Random Forest: 8.32611
# Average R2 on all folds using Random Forest: 0.69327
# Average MAPE on all folds using Random Forest: 34.89997
#
# Depth = 115
# Average RMSE on all folds using Random Forest: 8.34854
# Average R2 on all folds using Random Forest: 0.6931
# Average MAPE on all folds using Random Forest: 34.90443
#
# Depth = 116
# Average RMSE on all folds using Random Forest: 8.40816
# Average R2 on all folds using Random Forest: 0.68875
# Average MAPE on all folds using Random Forest: 34.92171
#
# Depth = 117
# Average RMSE on all folds using Random Forest: 8.32509
# Average R2 on all folds using Random Forest: 0.69351
# Average MAPE on all folds using Random Forest: 35.19999
#
# Depth = 118
# Average RMSE on all folds using Random Forest: 8.35487
# Average R2 on all folds using Random Forest: 0.69236
# Average MAPE on all folds using Random Forest: 34.71912
#
# Depth = 119
# Average RMSE on all folds using Random Forest: 8.33004
# Average R2 on all folds using Random Forest: 0.69421
# Average MAPE on all folds using Random Forest: 35.05761
#
# Depth = 120
# Average RMSE on all folds using Random Forest: 8.31732
# Average R2 on all folds using Random Forest: 0.69527
# Average MAPE on all folds using Random Forest: 35.09286
#
# Depth = 121
# Average RMSE on all folds using Random Forest: 8.33001
# Average R2 on all folds using Random Forest: 0.69308
# Average MAPE on all folds using Random Forest: 34.99801
#
# Depth = 122
# Average RMSE on all folds using Random Forest: 8.35447
# Average R2 on all folds using Random Forest: 0.6915
# Average MAPE on all folds using Random Forest: 35.61366
#
# Depth = 123
# Average RMSE on all folds using Random Forest: 8.35618
# Average R2 on all folds using Random Forest: 0.69277
# Average MAPE on all folds using Random Forest: 35.26933
#
# Depth = 124
# Average RMSE on all folds using Random Forest: 8.41603
# Average R2 on all folds using Random Forest: 0.68752
# Average MAPE on all folds using Random Forest: 35.03694
#
# Depth = 125
# Average RMSE on all folds using Random Forest: 8.29533
# Average R2 on all folds using Random Forest: 0.69695
# Average MAPE on all folds using Random Forest: 34.6087
#
# Depth = 126
# Average RMSE on all folds using Random Forest: 8.42045
# Average R2 on all folds using Random Forest: 0.68798
# Average MAPE on all folds using Random Forest: 35.913
#
# Depth = 127
# Average RMSE on all folds using Random Forest: 8.34635
# Average R2 on all folds using Random Forest: 0.69146
# Average MAPE on all folds using Random Forest: 35.49141
#
# Depth = 128
# Average RMSE on all folds using Random Forest: 8.41258
# Average R2 on all folds using Random Forest: 0.68767
# Average MAPE on all folds using Random Forest: 35.66004
#
# Depth = 129
# Average RMSE on all folds using Random Forest: 8.36819
# Average R2 on all folds using Random Forest: 0.69117
# Average MAPE on all folds using Random Forest: 34.944
#
# Depth = 130
# Average RMSE on all folds using Random Forest: 8.37061
# Average R2 on all folds using Random Forest: 0.69006
# Average MAPE on all folds using Random Forest: 35.38821
#
# Depth = 131
# Average RMSE on all folds using Random Forest: 8.32442
# Average R2 on all folds using Random Forest: 0.69531
# Average MAPE on all folds using Random Forest: 34.97656
#
# Depth = 132
# Average RMSE on all folds using Random Forest: 8.37167
# Average R2 on all folds using Random Forest: 0.69034
# Average MAPE on all folds using Random Forest: 35.26436
#
# Depth = 133
# Average RMSE on all folds using Random Forest: 8.36595
# Average R2 on all folds using Random Forest: 0.69199
# Average MAPE on all folds using Random Forest: 35.86695
#
# Depth = 134
# Average RMSE on all folds using Random Forest: 8.34131
# Average R2 on all folds using Random Forest: 0.69226
# Average MAPE on all folds using Random Forest: 35.84426
#
# Depth = 135
# Average RMSE on all folds using Random Forest: 8.36311
# Average R2 on all folds using Random Forest: 0.69114
# Average MAPE on all folds using Random Forest: 35.74744
#
# Depth = 136
# Average RMSE on all folds using Random Forest: 8.35087
# Average R2 on all folds using Random Forest: 0.69319
# Average MAPE on all folds using Random Forest: 35.38208
#
# Depth = 137
# Average RMSE on all folds using Random Forest: 8.38964
# Average R2 on all folds using Random Forest: 0.68991
# Average MAPE on all folds using Random Forest: 35.56922
#
# Depth = 138
# Average RMSE on all folds using Random Forest: 8.31406
# Average R2 on all folds using Random Forest: 0.69517
# Average MAPE on all folds using Random Forest: 35.65423
#
# Depth = 139
# Average RMSE on all folds using Random Forest: 8.34859
# Average R2 on all folds using Random Forest: 0.69242
# Average MAPE on all folds using Random Forest: 35.45137
#
# Depth = 140
# Average RMSE on all folds using Random Forest: 8.30635
# Average R2 on all folds using Random Forest: 0.69578
# Average MAPE on all folds using Random Forest: 36.15196
#
# Depth = 141
# Average RMSE on all folds using Random Forest: 8.36037
# Average R2 on all folds using Random Forest: 0.69214
# Average MAPE on all folds using Random Forest: 35.83943
#
# Depth = 142
# Average RMSE on all folds using Random Forest: 8.44051
# Average R2 on all folds using Random Forest: 0.68549
# Average MAPE on all folds using Random Forest: 35.12628
#
# Depth = 143
# Average RMSE on all folds using Random Forest: 8.46351
# Average R2 on all folds using Random Forest: 0.68418
# Average MAPE on all folds using Random Forest: 36.16047
#
# Depth = 144
# Average RMSE on all folds using Random Forest: 8.3905
# Average R2 on all folds using Random Forest: 0.68978
# Average MAPE on all folds using Random Forest: 35.58605
#
# Depth = 145
# Average RMSE on all folds using Random Forest: 8.41496
# Average R2 on all folds using Random Forest: 0.68803
# Average MAPE on all folds using Random Forest: 35.1945
#
# Depth = 146
# Average RMSE on all folds using Random Forest: 8.34984
# Average R2 on all folds using Random Forest: 0.69156
# Average MAPE on all folds using Random Forest: 35.23696
#
# Depth = 147
# Average RMSE on all folds using Random Forest: 8.3535
# Average R2 on all folds using Random Forest: 0.69277
# Average MAPE on all folds using Random Forest: 35.17612
#
# Depth = 148
# Average RMSE on all folds using Random Forest: 8.30757
# Average R2 on all folds using Random Forest: 0.69595
# Average MAPE on all folds using Random Forest: 35.36493
#
# Depth = 149
# Average RMSE on all folds using Random Forest: 8.3442
# Average R2 on all folds using Random Forest: 0.69227
# Average MAPE on all folds using Random Forest: 34.85342
#
# Depth = 150
# Average RMSE on all folds using Random Forest: 8.37677
# Average R2 on all folds using Random Forest: 0.69022
# Average MAPE on all folds using Random Forest: 35.00027
#
# Depth = 151
# Average RMSE on all folds using Random Forest: 8.32711
# Average R2 on all folds using Random Forest: 0.69381
# Average MAPE on all folds using Random Forest: 35.34423
#
# Depth = 152
# Average RMSE on all folds using Random Forest: 8.26682
# Average R2 on all folds using Random Forest: 0.69844
# Average MAPE on all folds using Random Forest: 35.32609
#
# Depth = 153
# Average RMSE on all folds using Random Forest: 8.38127
# Average R2 on all folds using Random Forest: 0.69053
# Average MAPE on all folds using Random Forest: 35.29044
#
# Depth = 154
# Average RMSE on all folds using Random Forest: 8.3518
# Average R2 on all folds using Random Forest: 0.69205
# Average MAPE on all folds using Random Forest: 35.64089
#
# Depth = 155
# Average RMSE on all folds using Random Forest: 8.37563
# Average R2 on all folds using Random Forest: 0.69111
# Average MAPE on all folds using Random Forest: 35.50259
#
# Depth = 156
# Average RMSE on all folds using Random Forest: 8.37852
# Average R2 on all folds using Random Forest: 0.69021
# Average MAPE on all folds using Random Forest: 35.8002
#
# Depth = 157
# Average RMSE on all folds using Random Forest: 8.38671
# Average R2 on all folds using Random Forest: 0.68982
# Average MAPE on all folds using Random Forest: 35.4711
#
# Depth = 158
# Average RMSE on all folds using Random Forest: 8.33863
# Average R2 on all folds using Random Forest: 0.69375
# Average MAPE on all folds using Random Forest: 35.31793
#
# Depth = 159
# Average RMSE on all folds using Random Forest: 8.28249
# Average R2 on all folds using Random Forest: 0.69721
# Average MAPE on all folds using Random Forest: 34.89118
#
# Depth = 160
# Average RMSE on all folds using Random Forest: 8.39205
# Average R2 on all folds using Random Forest: 0.68973
# Average MAPE on all folds using Random Forest: 35.37095
#
# Depth = 161
# Average RMSE on all folds using Random Forest: 8.40021
# Average R2 on all folds using Random Forest: 0.68867
# Average MAPE on all folds using Random Forest: 35.34143
#
# Depth = 162
# Average RMSE on all folds using Random Forest: 8.26529
# Average R2 on all folds using Random Forest: 0.69917
# Average MAPE on all folds using Random Forest: 35.54102
#
# Depth = 163
# Average RMSE on all folds using Random Forest: 8.31489
# Average R2 on all folds using Random Forest: 0.69489
# Average MAPE on all folds using Random Forest: 34.93774
#
# Depth = 164
# Average RMSE on all folds using Random Forest: 8.34337
# Average R2 on all folds using Random Forest: 0.69333
# Average MAPE on all folds using Random Forest: 34.30465
#
# Depth = 165
# Average RMSE on all folds using Random Forest: 8.33527
# Average R2 on all folds using Random Forest: 0.69257
# Average MAPE on all folds using Random Forest: 34.94049
#
# Depth = 166
# Average RMSE on all folds using Random Forest: 8.38713
# Average R2 on all folds using Random Forest: 0.68871
# Average MAPE on all folds using Random Forest: 36.07608
#
# Depth = 167
# Average RMSE on all folds using Random Forest: 8.32611
# Average R2 on all folds using Random Forest: 0.69467
# Average MAPE on all folds using Random Forest: 35.77373
#
# Depth = 168
# Average RMSE on all folds using Random Forest: 8.28971
# Average R2 on all folds using Random Forest: 0.69614
# Average MAPE on all folds using Random Forest: 34.83729
#
# Depth = 169
# Average RMSE on all folds using Random Forest: 8.33792
# Average R2 on all folds using Random Forest: 0.69393
# Average MAPE on all folds using Random Forest: 35.39692
#
# Depth = 170
# Average RMSE on all folds using Random Forest: 8.37882
# Average R2 on all folds using Random Forest: 0.69
# Average MAPE on all folds using Random Forest: 35.75815
#
# Depth = 171
# Average RMSE on all folds using Random Forest: 8.38412
# Average R2 on all folds using Random Forest: 0.68994
# Average MAPE on all folds using Random Forest: 35.30308
#
# Depth = 172
# Average RMSE on all folds using Random Forest: 8.34008
# Average R2 on all folds using Random Forest: 0.69302
# Average MAPE on all folds using Random Forest: 34.97125
#
# Depth = 173
# Average RMSE on all folds using Random Forest: 8.41012
# Average R2 on all folds using Random Forest: 0.68677
# Average MAPE on all folds using Random Forest: 35.7336
#
# Depth = 174
# Average RMSE on all folds using Random Forest: 8.34396
# Average R2 on all folds using Random Forest: 0.69262
# Average MAPE on all folds using Random Forest: 35.60214
#
# Depth = 175
# Average RMSE on all folds using Random Forest: 8.34315
# Average R2 on all folds using Random Forest: 0.69241
# Average MAPE on all folds using Random Forest: 35.03749
#
# Depth = 176
# Average RMSE on all folds using Random Forest: 8.40355
# Average R2 on all folds using Random Forest: 0.68833
# Average MAPE on all folds using Random Forest: 35.63494
#
# Depth = 177
# Average RMSE on all folds using Random Forest: 8.38946
# Average R2 on all folds using Random Forest: 0.68918
# Average MAPE on all folds using Random Forest: 35.40406
#
# Depth = 178
# Average RMSE on all folds using Random Forest: 8.40589
# Average R2 on all folds using Random Forest: 0.68799
# Average MAPE on all folds using Random Forest: 35.39482
#
# Depth = 179
# Average RMSE on all folds using Random Forest: 8.34984
# Average R2 on all folds using Random Forest: 0.69142
# Average MAPE on all folds using Random Forest: 35.47823
#
# Depth = 180
# Average RMSE on all folds using Random Forest: 8.41617
# Average R2 on all folds using Random Forest: 0.68677
# Average MAPE on all folds using Random Forest: 35.15926
#
# Depth = 181
# Average RMSE on all folds using Random Forest: 8.36025
# Average R2 on all folds using Random Forest: 0.69235
# Average MAPE on all folds using Random Forest: 35.00597
#
# Depth = 182
# Average RMSE on all folds using Random Forest: 8.38269
# Average R2 on all folds using Random Forest: 0.69088
# Average MAPE on all folds using Random Forest: 35.36658
#
# Depth = 183
# Average RMSE on all folds using Random Forest: 8.34952
# Average R2 on all folds using Random Forest: 0.69323
# Average MAPE on all folds using Random Forest: 35.18347
#
# Depth = 184
# Average RMSE on all folds using Random Forest: 8.37702
# Average R2 on all folds using Random Forest: 0.69084
# Average MAPE on all folds using Random Forest: 35.59403
#
# Depth = 185
# Average RMSE on all folds using Random Forest: 8.31201
# Average R2 on all folds using Random Forest: 0.69474
# Average MAPE on all folds using Random Forest: 34.89564
#
# Depth = 186
# Average RMSE on all folds using Random Forest: 8.36794
# Average R2 on all folds using Random Forest: 0.69059
# Average MAPE on all folds using Random Forest: 35.75182
#
# Depth = 187
# Average RMSE on all folds using Random Forest: 8.42323
# Average R2 on all folds using Random Forest: 0.68738
# Average MAPE on all folds using Random Forest: 35.7442
#
# Depth = 188
# Average RMSE on all folds using Random Forest: 8.33528
# Average R2 on all folds using Random Forest: 0.69271
# Average MAPE on all folds using Random Forest: 35.32969
#
# Depth = 189
# Average RMSE on all folds using Random Forest: 8.35661
# Average R2 on all folds using Random Forest: 0.69251
# Average MAPE on all folds using Random Forest: 35.61601
#
# Depth = 190
# Average RMSE on all folds using Random Forest: 8.4022
# Average R2 on all folds using Random Forest: 0.68868
# Average MAPE on all folds using Random Forest: 35.03749
#
# Depth = 191
# Average RMSE on all folds using Random Forest: 8.29614
# Average R2 on all folds using Random Forest: 0.69525
# Average MAPE on all folds using Random Forest: 35.16162
#
# Depth = 192
# Average RMSE on all folds using Random Forest: 8.34308
# Average R2 on all folds using Random Forest: 0.69272
# Average MAPE on all folds using Random Forest: 35.30343
#
# Depth = 193
# Average RMSE on all folds using Random Forest: 8.36078
# Average R2 on all folds using Random Forest: 0.69163
# Average MAPE on all folds using Random Forest: 35.6623
#
# Depth = 194
# Average RMSE on all folds using Random Forest: 8.31455
# Average R2 on all folds using Random Forest: 0.69118
# Average MAPE on all folds using Random Forest: 34.7614
#
# Depth = 195
# Average RMSE on all folds using Random Forest: 8.39127
# Average R2 on all folds using Random Forest: 0.68958
# Average MAPE on all folds using Random Forest: 35.31311
#
# Depth = 196
# Average RMSE on all folds using Random Forest: 8.34918
# Average R2 on all folds using Random Forest: 0.69314
# Average MAPE on all folds using Random Forest: 35.18958
#
# Depth = 197
# Average RMSE on all folds using Random Forest: 8.34265
# Average R2 on all folds using Random Forest: 0.69245
# Average MAPE on all folds using Random Forest: 35.79582
#
# Depth = 198
# Average RMSE on all folds using Random Forest: 8.34767
# Average R2 on all folds using Random Forest: 0.69316
# Average MAPE on all folds using Random Forest: 35.49716
#
# Depth = 199
# Average RMSE on all folds using Random Forest: 8.33943
# Average R2 on all folds using Random Forest: 0.6911
# Average MAPE on all folds using Random Forest: 34.87962
#
# Best depth for RMSE is 162 with RMSE = 8.26529
# Best depth for R2 is 162 with R2 = 0.69917
# Best depth for R2 is 164 with MAPE = 34.30465

# %%
model_checkpoint = '/content/drive/MyDrive/STUDYING/HK2 2020-2021/Modern Problems in Technology/best_rf_cua_Giang.pkl'

with open(model_checkpoint, 'rb') as file:  
    model = pickle.load(file)

model
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=162, n_jobs=None, oob_score=False,
#                       random_state=20, verbose=0, warm_start=False)
