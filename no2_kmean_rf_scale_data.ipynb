# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.neighbors import KNeighborsClassifier

from sklearn.linear_model import LinearRegression

import numpy as np
from sklearn.model_selection import KFold

from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

import os
import math
import copy

# %%
# Mouting with google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Config path and variable

# %%
data_folder = '/content/drive/MyDrive/Modern Problems in Technology'

# Choose one of 2 versions below:
# Uncomment below line to choose scaled data version
# data_version = 'data_processed_withscale.csv'

# Uncomment below line to choose non-scaled data version
data_version = 'data_processed_withscale.csv'


data = pd.read_csv(os.path.join(data_folder, data_version))

data
# Out:
#           lat       lon        NO2  ...  pplt_dens  road_dens  cluster
# 0     21.0491  105.8831   0.000000  ...   0.062616   0.204322        4
# 1     21.0491  105.8831   0.000000  ...   0.062616   0.204322        4
# 2     21.0491  105.8831  41.310400  ...   0.062616   0.204322        4
# 3     21.0491  105.8831  39.379204  ...   0.062616   0.204322        4
# 4     21.0491  105.8831  39.901879  ...   0.062616   0.204322        4
# ...       ...       ...        ...  ...        ...        ...      ...
# 5455  21.0197  105.8147  18.995833  ...   1.000000   0.793592        4
# 5456  21.0197  105.8147  23.241667  ...   1.000000   0.793592        4
# 5457  21.0197  105.8147  16.816667  ...   1.000000   0.793592        1
# 5458  21.0197  105.8147  21.595833  ...   1.000000   0.793592        1
# 5459  21.0197  105.8147  19.058333  ...   1.000000   0.793592        4
#
# [5460 rows x 15 columns]

# %% [markdown]
# ## Reading data version

# %%
data = pd.read_csv(os.path.join(data_folder, data_version))

data
# Out:
#           lat       lon        NO2  ...  pplt_dens  road_dens  cluster
# 0     21.0491  105.8831   0.000000  ...   0.062616   0.204322        4
# 1     21.0491  105.8831   0.000000  ...   0.062616   0.204322        4
# 2     21.0491  105.8831  41.310400  ...   0.062616   0.204322        4
# 3     21.0491  105.8831  39.379204  ...   0.062616   0.204322        4
# 4     21.0491  105.8831  39.901879  ...   0.062616   0.204322        4
# ...       ...       ...        ...  ...        ...        ...      ...
# 5455  21.0197  105.8147  18.995833  ...   1.000000   0.793592        4
# 5456  21.0197  105.8147  23.241667  ...   1.000000   0.793592        4
# 5457  21.0197  105.8147  16.816667  ...   1.000000   0.793592        1
# 5458  21.0197  105.8147  21.595833  ...   1.000000   0.793592        1
# 5459  21.0197  105.8147  19.058333  ...   1.000000   0.793592        4
#
# [5460 rows x 15 columns]

# %%
# data = data[data.cluster != 2]
# Unique cluster value
data['cluster'].unique()
# Out:
# array([4, 3, 1, 0, 2])

# %% [markdown]
# ## Remove Invalid NO2 values

# %%
# Run this if you want to remove invalid no2 values

data = data[(data.NO2 > 0) & (data.NO2 < 100)]
data[data.NO2 > 100]
# Out:
# Empty DataFrame
# Columns: [lat, lon, NO2, pblh, press, rh, tmp, wspd, dpt_00, dpt_06, dpt_12, dpt_18, pplt_dens, road_dens, cluster]
# Index: []

# %% [markdown]
# ## Drop some columns of data

# %%
def drop_cols(df, colName):
    if colName in df:
      df.drop(colName, axis='columns', inplace=True)

# drop_cols(data, "press")

# %% [markdown]
# ## Create multiple datatset by dropping each colums of original dataset

# %%
# columns = data.columns
# for col in range(3, 15):
#   print(columns[col])
dropDatas = [data]
# print(dropDatas[0])
# for i in range(3, 15):
#   print(columns[i])
#   data_copy = copy.deepcopy(data)
#   drop_cols(data_copy, columns[i])
#   dropDatas.append(data_copy)
  # print(len(dropDatas[i-3].columns))
data_copy = copy.deepcopy(data)
drop_cols(data_copy, "cluster")
dropDatas.append(data_copy)
len(dropDatas)
# Out:
# 2

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %% [markdown]
# ## Convert to numpy for feeding model

# %%
for idx in range(0, 2):
  print("---------------------------------------------")
  if (idx == 0):
      print()
      print("Original data")
      print()
      print("---------------------------------------------")
  else:
      print()
      print("Data without cluster")
      print()
      print("---------------------------------------------")
  
  tmpData = dropDatas[idx-2]
  X = tmpData.drop('NO2', axis = 'columns')
  X_arr = X.to_numpy()

  y = tmpData['NO2']
  y_arr = y.to_numpy()

  print(X.shape, y.shape)


  # # List of RMSE on all folds
  # rmses_rf = []
  # mapes_rf = []
  # r2s_rf = []

  # rmses_lr = []
  # mapes_lr = []
  # r2s_lr = []

  # # Fold tracking
  # i = 1
  # # Depth of Random Forest
  # depth = 50
  # # Number of split
  # split_number = 5

  # kf = KFold(n_splits=split_number, random_state=None, shuffle=True)
  # kf.get_n_splits(X)

  # for train_index, test_index in kf.split(X):
  #   min_rmse_rf = 10000
  #   min_r2_rf = 10000
  #   min_mape_rf = 10000

  #   min_rmse_lr = 10000
  #   min_r2_lr = 10000
  #   min_mape_lr = 10000

  #   # print("TRAIN:", train_index, "TEST:", test_index)
  #   X_train, X_test = X_arr[train_index], X_arr[test_index]
  #   y_train, y_test = y_arr[train_index], y_arr[test_index]
  #   print(len(train_index), len(test_index))

  #   print('Fold {}:'.format(i))

  #   # Random Forest
  #   for d in range(1, depth):
  #     rf = RandomForestRegressor(n_estimators = d, random_state = 20)
  #     rf.fit(X_train, y_train)
  #     rf_predicts = rf.predict(X_test)
  #     # Calculate RMSE
  #     rmse_rf = math.sqrt(mean_squared_error(y_test, rf_predicts))
  #     # Calculate R2 Score
  #     r2_rf = r2_score(y_test, rf_predicts)
  #     # Calculate mean absolute error (MAE NOT MAPE)
  #     # mape_rf = mean_absolute_error(y_test, rf_predicts)
  #     mape_rf = mean_absolute_percentage_error(y_test, rf_predicts)
      
  #     # Saving best errors
  #     if rmse_rf < min_rmse_rf:
  #       min_rmse_rf = rmse_rf
  #     if r2_rf < min_r2_rf:
  #       min_r2_rf = r2_rf
  #     if mape_rf < min_mape_rf:
  #       min_mape_rf = mape_rf

  #   rmses_rf.append(min_rmse_rf)
  #   r2s_rf.append(min_r2_rf)
  #   mapes_rf.append(min_mape_rf)

  #   print('Min RMSE for Random Forest:'.format(i), min_rmse_rf)
  #   print('Min R2 for Random Forest:'.format(i), min_r2_rf)
  #   print('Min MAPE for Random Forest:'.format(i), min_mape_rf)
  #   print()

  #   # Linear Regression
  #   lr = LinearRegression()
  #   lr.fit(X_train, y_train)
  #   lr_predicts = lr.predict(X_test)
  #   # Calculate RMSE
  #   rmse_lr = math.sqrt(mean_squared_error(y_test, lr_predicts))
  #   # Calculate R2 Score
  #   r2_lr = r2_score(y_test, lr_predicts)
  #   # Calculate mean absolute error (MAE NOT MAPE)
  #   # mape_lr = mean_absolute_error(y_test, lr_predicts)
  #   mape_lr = mean_absolute_percentage_error(y_test, rf_predicts)

  #   if rmse_lr < min_rmse_lr:
  #     min_rmse_lr = rmse_lr
  #   if r2_lr < min_r2_lr:
  #     min_r2_lr = r2_lr
  #   if mape_lr < min_mape_lr:
  #     min_mape_lr = mape_lr

  #   # a={'true': y_test, 'predict':predicts}
  #   # display(pd.DataFrame(a))

  #   rmses_lr.append(min_rmse_lr)
  #   r2s_lr.append(min_r2_lr)
  #   mapes_lr.append(min_mape_lr)

  #   print('Min RMSE for Linear Regression:'.format(i), min_rmse_lr)
  #   print('Min R2 for Linear Regression:'.format(i), min_r2_lr)
  #   print('Min MAPE for Linear Regression:'.format(i), min_mape_lr)
  #   print()
  #   print()

  #   i += 1
  # if (idx == 2):
  #     print("Original data")
  #     print()
  # else:
  #     print("Data without " + columns[idx])
  #     print()
  # print()
  # print('Average RMSE on all folds using Random Forest:', np.average(rmses_rf))
  # print('Average R2 on all folds using Random Forest:', np.average(r2s_rf))
  # print('Average MAPE on all folds using Random Forest:', np.average(mapes_rf))

  # print()
  # print('Average RMSE on all folds using Linear Regression:', np.average(rmses_lr))
  # print('Average R2 on all folds using Linear Regression:', np.average(r2s_lr))
  # print('Average MAPE on all folds using Linear Regression:', np.average(mapes_lr))

  # List of RMSE on all folds
# rmses_rf = []
# mapes_rf = []
# r2s_rf = []

# rmses_lr = []
# mapes_lr = []
# r2s_lr = []

  # Fold tracking
  i = 1
  # Depth of Random Forest
  depth = 200
  # Number of split
  split_number = 10

  map_depth_rmse = {}
  map_depth_r2 = {}
  map_depth_mape = {}

  # How many number want to round with loss (1.424 if precision =3 for example)
  precision = 5

  def MAPE(Y_actual,Y_Predicted):
      mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
      return mape

  def get_key(dict, val):
    for key, value in dict.items():
          if val == value:
              return key

    return "key doesn't exist"

  # kf = KFold(n_splits=split_number, random_state=None, shuffle=None)
  # kf.get_n_splits(X)

  # for train_index, test_index in kf.split(X):
  #   min_rmse_rf = 10000
  #   min_r2_rf = 10000
  #   min_mape_rf = 10000

  #   min_rmse_lr = 10000
  #   min_r2_lr = 10000
  #   min_mape_lr = 10000

  #   # print("TRAIN:", train_index, "TEST:", test_index)
  #   X_train, X_test = X_arr[train_index], X_arr[test_index]
  #   y_train, y_test = y_arr[train_index], y_arr[test_index]
  #   # print(len(train_index), len(test_index))

  #   print('Fold {}:'.format(i))

    # Random Forest
  for d in range(1, depth):
    kf = KFold(n_splits=split_number, random_state=None, shuffle=True)
    kf.get_n_splits(X)

    rmses_rf = []
    mapes_rf = []
    r2s_rf = []

    rmses_lr = []
    mapes_lr = []
    r2s_lr = []

    for train_index, test_index in kf.split(X):
      min_rmse_rf = 10000
      min_r2_rf = 0
      min_mape_rf = 10000

      # min_rmse_lr = 10000
      # min_r2_lr = 10000
      # min_mape_lr = 10000

      # print("TRAIN:", train_index, "TEST:", test_index)
      X_train, X_test = X_arr[train_index], X_arr[test_index]
      y_train, y_test = y_arr[train_index], y_arr[test_index]
      # print(len(train_index), len(test_index))

      # print('Fold {}:'.format(i))
      rf = RandomForestRegressor(n_estimators = d, random_state = 20)
      rf.fit(X_train, y_train)
      rf_predicts = rf.predict(X_test)
      # Calculate RMSE
      rmse_rf = math.sqrt(mean_squared_error(y_test, rf_predicts))
      # Calculate R2 Score
      r2_rf = r2_score(y_test, rf_predicts)
      # Calculate mean absolute error (MAE NOT MAPE)
      # mape_rf = mean_absolute_error(y_test, rf_predicts)
      mape_rf = MAPE(y_test, rf_predicts)

      # With each depth, calculate and save losses of all fold
      rmses_rf.append(rmse_rf)
      r2s_rf.append(r2_rf)
      mapes_rf.append(mape_rf)

    # After each depth, save average loss to find best depth
    average_rmse_rf = round(np.average(rmses_rf), precision)
    average_r2_rf = round(np.average(r2s_rf), precision)
    average_mape_rf = round(np.average(mape_rf), precision)

    map_depth_rmse[d] = average_rmse_rf
    map_depth_r2[d] = average_r2_rf
    map_depth_mape[d] = average_mape_rf
    
    print('Depth =', d)
    print('Average RMSE on all folds using Random Forest:', average_rmse_rf)
    print('Average R2 on all folds using Random Forest:', average_r2_rf)
    print('Average MAPE on all folds using Random Forest:', average_mape_rf)
    print()

  # print(map_depth_rmse)
  # print(map_depth_r2)

  min_rmse = min(map_depth_rmse.values())
  max_r2 = max(map_depth_r2.values())
  min_mape = min(map_depth_mape.values())

  print('Best depth for RMSE is {} with RMSE = {}'.format(get_key(map_depth_rmse, min_rmse), min_rmse))
  print('Best depth for R2 is {} with R2 = {}'.format(get_key(map_depth_r2, max_r2), max_r2))
  print('Best depth for MAPE is {} with MAPE = {}'.format(get_key(map_depth_mape, min_mape), min_mape))
# Out:
# ---------------------------------------------
#
# Original data
#
# ---------------------------------------------
# (4679, 14) (4679,)
# Depth = 1
# Average RMSE on all folds using Random Forest: 14.17766
# Average R2 on all folds using Random Forest: 0.11267
# Average MAPE on all folds using Random Forest: 50.97603
#
# Depth = 2
# Average RMSE on all folds using Random Forest: 11.91888
# Average R2 on all folds using Random Forest: 0.37342
# Average MAPE on all folds using Random Forest: 37.92736
#
# Depth = 3
# Average RMSE on all folds using Random Forest: 11.03418
# Average R2 on all folds using Random Forest: 0.46272
# Average MAPE on all folds using Random Forest: 37.89522
#
# Depth = 4
# Average RMSE on all folds using Random Forest: 10.81494
# Average R2 on all folds using Random Forest: 0.48144
# Average MAPE on all folds using Random Forest: 61.0081
#
# Depth = 5
# Average RMSE on all folds using Random Forest: 10.71975
# Average R2 on all folds using Random Forest: 0.49191
# Average MAPE on all folds using Random Forest: 36.65676
#
# Depth = 6
# Average RMSE on all folds using Random Forest: 10.36382
# Average R2 on all folds using Random Forest: 0.52614
# Average MAPE on all folds using Random Forest: 111.3261
#
# Depth = 7
# Average RMSE on all folds using Random Forest: 10.28502
# Average R2 on all folds using Random Forest: 0.5342
# Average MAPE on all folds using Random Forest: 35.22873
#
# Depth = 8
# Average RMSE on all folds using Random Forest: 10.31164
# Average R2 on all folds using Random Forest: 0.53018
# Average MAPE on all folds using Random Forest: 37.67112
#
# Depth = 9
# Average RMSE on all folds using Random Forest: 10.23755
# Average R2 on all folds using Random Forest: 0.5378
# Average MAPE on all folds using Random Forest: 36.70724
#
# Depth = 10
# Average RMSE on all folds using Random Forest: 10.17311
# Average R2 on all folds using Random Forest: 0.54277
# Average MAPE on all folds using Random Forest: 77.45292
#
# Depth = 11
# Average RMSE on all folds using Random Forest: 10.01421
# Average R2 on all folds using Random Forest: 0.55788
# Average MAPE on all folds using Random Forest: 31.33322
#
# Depth = 12
# Average RMSE on all folds using Random Forest: 10.04976
# Average R2 on all folds using Random Forest: 0.55284
# Average MAPE on all folds using Random Forest: 31.65467
#
# Depth = 13
# Average RMSE on all folds using Random Forest: 10.05016
# Average R2 on all folds using Random Forest: 0.55492
# Average MAPE on all folds using Random Forest: 36.30554
#
# Depth = 14
# Average RMSE on all folds using Random Forest: 10.05326
# Average R2 on all folds using Random Forest: 0.55311
# Average MAPE on all folds using Random Forest: 34.94519
#
# Depth = 15
# Average RMSE on all folds using Random Forest: 10.0421
# Average R2 on all folds using Random Forest: 0.55385
# Average MAPE on all folds using Random Forest: 37.30148
#
# Depth = 16
# Average RMSE on all folds using Random Forest: 9.87644
# Average R2 on all folds using Random Forest: 0.57009
# Average MAPE on all folds using Random Forest: 34.18277
#
# Depth = 17
# Average RMSE on all folds using Random Forest: 9.95716
# Average R2 on all folds using Random Forest: 0.5607
# Average MAPE on all folds using Random Forest: 58.09418
#
# Depth = 18
# Average RMSE on all folds using Random Forest: 9.92573
# Average R2 on all folds using Random Forest: 0.56504
# Average MAPE on all folds using Random Forest: 36.75719
#
# Depth = 19
# Average RMSE on all folds using Random Forest: 9.91171
# Average R2 on all folds using Random Forest: 0.56693
# Average MAPE on all folds using Random Forest: 38.4507
#
# Depth = 20
# Average RMSE on all folds using Random Forest: 9.83969
# Average R2 on all folds using Random Forest: 0.57353
# Average MAPE on all folds using Random Forest: 53.96025
#
# Depth = 21
# Average RMSE on all folds using Random Forest: 9.84654
# Average R2 on all folds using Random Forest: 0.57348
# Average MAPE on all folds using Random Forest: 35.29649
#
# Depth = 22
# Average RMSE on all folds using Random Forest: 9.79922
# Average R2 on all folds using Random Forest: 0.57629
# Average MAPE on all folds using Random Forest: 35.57002
#
# Depth = 23
# Average RMSE on all folds using Random Forest: 9.92226
# Average R2 on all folds using Random Forest: 0.56443
# Average MAPE on all folds using Random Forest: 35.96269
#
# Depth = 24
# Average RMSE on all folds using Random Forest: 9.8579
# Average R2 on all folds using Random Forest: 0.57215
# Average MAPE on all folds using Random Forest: 33.33214
#
# Depth = 25
# Average RMSE on all folds using Random Forest: 9.74313
# Average R2 on all folds using Random Forest: 0.58171
# Average MAPE on all folds using Random Forest: 81.8851
#
# Depth = 26
# Average RMSE on all folds using Random Forest: 9.8213
# Average R2 on all folds using Random Forest: 0.57275
# Average MAPE on all folds using Random Forest: 77.56974
#
# Depth = 27
# Average RMSE on all folds using Random Forest: 9.76482
# Average R2 on all folds using Random Forest: 0.57923
# Average MAPE on all folds using Random Forest: 33.57908
#
# Depth = 28
# Average RMSE on all folds using Random Forest: 9.78277
# Average R2 on all folds using Random Forest: 0.57902
# Average MAPE on all folds using Random Forest: 36.17076
#
# Depth = 29
# Average RMSE on all folds using Random Forest: 9.83133
# Average R2 on all folds using Random Forest: 0.57415
# Average MAPE on all folds using Random Forest: 53.20088
#
# Depth = 30
# Average RMSE on all folds using Random Forest: 9.86568
# Average R2 on all folds using Random Forest: 0.57051
# Average MAPE on all folds using Random Forest: 38.58514
#
# Depth = 31
# Average RMSE on all folds using Random Forest: 9.69773
# Average R2 on all folds using Random Forest: 0.58615
# Average MAPE on all folds using Random Forest: 34.68956
#
# Depth = 32
# Average RMSE on all folds using Random Forest: 9.73846
# Average R2 on all folds using Random Forest: 0.58293
# Average MAPE on all folds using Random Forest: 33.3732
#
# Depth = 33
# Average RMSE on all folds using Random Forest: 9.81336
# Average R2 on all folds using Random Forest: 0.57429
# Average MAPE on all folds using Random Forest: 36.2256
#
# Depth = 34
# Average RMSE on all folds using Random Forest: 9.83744
# Average R2 on all folds using Random Forest: 0.57283
# Average MAPE on all folds using Random Forest: 35.20619
#
# Depth = 35
# Average RMSE on all folds using Random Forest: 9.86816
# Average R2 on all folds using Random Forest: 0.57019
# Average MAPE on all folds using Random Forest: 35.77811
#
# Depth = 36
# Average RMSE on all folds using Random Forest: 9.77551
# Average R2 on all folds using Random Forest: 0.57936
# Average MAPE on all folds using Random Forest: 53.19862
#
# Depth = 37
# Average RMSE on all folds using Random Forest: 9.83018
# Average R2 on all folds using Random Forest: 0.57273
# Average MAPE on all folds using Random Forest: 74.87572
#
# Depth = 38
# Average RMSE on all folds using Random Forest: 9.68013
# Average R2 on all folds using Random Forest: 0.58771
# Average MAPE on all folds using Random Forest: 54.46929
#
# Depth = 39
# Average RMSE on all folds using Random Forest: 9.77585
# Average R2 on all folds using Random Forest: 0.57796
# Average MAPE on all folds using Random Forest: 35.12895
#
# Depth = 40
# Average RMSE on all folds using Random Forest: 9.76767
# Average R2 on all folds using Random Forest: 0.57899
# Average MAPE on all folds using Random Forest: 35.88053
#
# Depth = 41
# Average RMSE on all folds using Random Forest: 9.7085
# Average R2 on all folds using Random Forest: 0.58365
# Average MAPE on all folds using Random Forest: 35.81022
#
# Depth = 42
# Average RMSE on all folds using Random Forest: 9.80781
# Average R2 on all folds using Random Forest: 0.57572
# Average MAPE on all folds using Random Forest: 35.3482
#
# Depth = 43
# Average RMSE on all folds using Random Forest: 9.77596
# Average R2 on all folds using Random Forest: 0.5778
# Average MAPE on all folds using Random Forest: 34.94617
#
# Depth = 44
# Average RMSE on all folds using Random Forest: 9.77496
# Average R2 on all folds using Random Forest: 0.57831
# Average MAPE on all folds using Random Forest: 36.24691
#
# Depth = 45
# Average RMSE on all folds using Random Forest: 9.70277
# Average R2 on all folds using Random Forest: 0.58531
# Average MAPE on all folds using Random Forest: 41.2634
#
# Depth = 46
# Average RMSE on all folds using Random Forest: 9.73625
# Average R2 on all folds using Random Forest: 0.58249
# Average MAPE on all folds using Random Forest: 33.11252
#
# Depth = 47
# Average RMSE on all folds using Random Forest: 9.76362
# Average R2 on all folds using Random Forest: 0.57917
# Average MAPE on all folds using Random Forest: 32.94203
#
# Depth = 48
# Average RMSE on all folds using Random Forest: 9.75557
# Average R2 on all folds using Random Forest: 0.5811
# Average MAPE on all folds using Random Forest: 48.37383
#
# Depth = 49
# Average RMSE on all folds using Random Forest: 9.74515
# Average R2 on all folds using Random Forest: 0.58242
# Average MAPE on all folds using Random Forest: 33.68496
#
# Depth = 50
# Average RMSE on all folds using Random Forest: 9.71829
# Average R2 on all folds using Random Forest: 0.58456
# Average MAPE on all folds using Random Forest: 31.51395
#
# Depth = 51
# Average RMSE on all folds using Random Forest: 9.69804
# Average R2 on all folds using Random Forest: 0.58581
# Average MAPE on all folds using Random Forest: 32.56607
#
# Depth = 52
# Average RMSE on all folds using Random Forest: 9.6221
# Average R2 on all folds using Random Forest: 0.59129
# Average MAPE on all folds using Random Forest: 34.8323
#
# Depth = 53
# Average RMSE on all folds using Random Forest: 9.68083
# Average R2 on all folds using Random Forest: 0.5873
# Average MAPE on all folds using Random Forest: 35.38981
#
# Depth = 54
# Average RMSE on all folds using Random Forest: 9.74984
# Average R2 on all folds using Random Forest: 0.58062
# Average MAPE on all folds using Random Forest: 36.20016
#
# Depth = 55
# Average RMSE on all folds using Random Forest: 9.82635
# Average R2 on all folds using Random Forest: 0.57362
# Average MAPE on all folds using Random Forest: 30.74377
#
# Depth = 56
# Average RMSE on all folds using Random Forest: 9.75877
# Average R2 on all folds using Random Forest: 0.58021
# Average MAPE on all folds using Random Forest: 53.72197
#
# Depth = 57
# Average RMSE on all folds using Random Forest: 9.7377
# Average R2 on all folds using Random Forest: 0.5817
# Average MAPE on all folds using Random Forest: 52.12815
#
# Depth = 58
# Average RMSE on all folds using Random Forest: 9.76531
# Average R2 on all folds using Random Forest: 0.57973
# Average MAPE on all folds using Random Forest: 34.20418
#
# Depth = 59
# Average RMSE on all folds using Random Forest: 9.76063
# Average R2 on all folds using Random Forest: 0.5798
# Average MAPE on all folds using Random Forest: 34.23766
#
# Depth = 60
# Average RMSE on all folds using Random Forest: 9.63592
# Average R2 on all folds using Random Forest: 0.58996
# Average MAPE on all folds using Random Forest: 34.77603
#
# Depth = 61
# Average RMSE on all folds using Random Forest: 9.67126
# Average R2 on all folds using Random Forest: 0.58703
# Average MAPE on all folds using Random Forest: 32.79403
#
# Depth = 62
# Average RMSE on all folds using Random Forest: 9.64665
# Average R2 on all folds using Random Forest: 0.58837
# Average MAPE on all folds using Random Forest: 34.36003
#
# Depth = 63
# Average RMSE on all folds using Random Forest: 9.73075
# Average R2 on all folds using Random Forest: 0.58144
# Average MAPE on all folds using Random Forest: 36.68288
#
# Depth = 64
# Average RMSE on all folds using Random Forest: 9.73719
# Average R2 on all folds using Random Forest: 0.58259
# Average MAPE on all folds using Random Forest: 34.69208
#
# Depth = 65
# Average RMSE on all folds using Random Forest: 9.75307
# Average R2 on all folds using Random Forest: 0.58153
# Average MAPE on all folds using Random Forest: 33.57084
#
# Depth = 66
# Average RMSE on all folds using Random Forest: 9.64925
# Average R2 on all folds using Random Forest: 0.58786
# Average MAPE on all folds using Random Forest: 75.54639
#
# Depth = 67
# Average RMSE on all folds using Random Forest: 9.69464
# Average R2 on all folds using Random Forest: 0.58518
# Average MAPE on all folds using Random Forest: 37.65965
#
# Depth = 68
# Average RMSE on all folds using Random Forest: 9.72678
# Average R2 on all folds using Random Forest: 0.58364
# Average MAPE on all folds using Random Forest: 36.92366
#
# Depth = 69
# Average RMSE on all folds using Random Forest: 9.70614
# Average R2 on all folds using Random Forest: 0.58509
# Average MAPE on all folds using Random Forest: 30.23329
#
# Depth = 70
# Average RMSE on all folds using Random Forest: 9.76569
# Average R2 on all folds using Random Forest: 0.57987
# Average MAPE on all folds using Random Forest: 35.03894
#
# Depth = 71
# Average RMSE on all folds using Random Forest: 9.7088
# Average R2 on all folds using Random Forest: 0.58317
# Average MAPE on all folds using Random Forest: 35.81403
#
# Depth = 72
# Average RMSE on all folds using Random Forest: 9.69864
# Average R2 on all folds using Random Forest: 0.58583
# Average MAPE on all folds using Random Forest: 38.33275
#
# Depth = 73
# Average RMSE on all folds using Random Forest: 9.71548
# Average R2 on all folds using Random Forest: 0.58426
# Average MAPE on all folds using Random Forest: 34.23493
#
# Depth = 74
# Average RMSE on all folds using Random Forest: 9.79487
# Average R2 on all folds using Random Forest: 0.57704
# Average MAPE on all folds using Random Forest: 32.16409
#
# Depth = 75
# Average RMSE on all folds using Random Forest: 9.72324
# Average R2 on all folds using Random Forest: 0.58122
# Average MAPE on all folds using Random Forest: 46.82338
#
# Depth = 76
# Average RMSE on all folds using Random Forest: 9.65957
# Average R2 on all folds using Random Forest: 0.58767
# Average MAPE on all folds using Random Forest: 36.68502
#
# Depth = 77
# Average RMSE on all folds using Random Forest: 9.73839
# Average R2 on all folds using Random Forest: 0.58112
# Average MAPE on all folds using Random Forest: 36.58887
#
# Depth = 78
# Average RMSE on all folds using Random Forest: 9.71945
# Average R2 on all folds using Random Forest: 0.58342
# Average MAPE on all folds using Random Forest: 33.90295
#
# Depth = 79
# Average RMSE on all folds using Random Forest: 9.67516
# Average R2 on all folds using Random Forest: 0.58657
# Average MAPE on all folds using Random Forest: 33.95266
#
# Depth = 80
# Average RMSE on all folds using Random Forest: 9.73774
# Average R2 on all folds using Random Forest: 0.58043
# Average MAPE on all folds using Random Forest: 53.60405
#
# Depth = 81
# Average RMSE on all folds using Random Forest: 9.70998
# Average R2 on all folds using Random Forest: 0.58335
# Average MAPE on all folds using Random Forest: 36.29453
#
# Depth = 82
# Average RMSE on all folds using Random Forest: 9.77791
# Average R2 on all folds using Random Forest: 0.57831
# Average MAPE on all folds using Random Forest: 34.93638
#
# Depth = 83
# Average RMSE on all folds using Random Forest: 9.72571
# Average R2 on all folds using Random Forest: 0.58101
# Average MAPE on all folds using Random Forest: 31.30264
#
# Depth = 84
# Average RMSE on all folds using Random Forest: 9.70033
# Average R2 on all folds using Random Forest: 0.58402
# Average MAPE on all folds using Random Forest: 36.39736
#
# Depth = 85
# Average RMSE on all folds using Random Forest: 9.66084
# Average R2 on all folds using Random Forest: 0.58607
# Average MAPE on all folds using Random Forest: 46.92641
#
# Depth = 86
# Average RMSE on all folds using Random Forest: 9.75963
# Average R2 on all folds using Random Forest: 0.57914
# Average MAPE on all folds using Random Forest: 39.24329
#
# Depth = 87
# Average RMSE on all folds using Random Forest: 9.6765
# Average R2 on all folds using Random Forest: 0.58724
# Average MAPE on all folds using Random Forest: 36.24019
#
# Depth = 88
# Average RMSE on all folds using Random Forest: 9.69735
# Average R2 on all folds using Random Forest: 0.5847
# Average MAPE on all folds using Random Forest: 51.63749
#
# Depth = 89
# Average RMSE on all folds using Random Forest: 9.65231
# Average R2 on all folds using Random Forest: 0.58989
# Average MAPE on all folds using Random Forest: 38.40407
#
# Depth = 90
# Average RMSE on all folds using Random Forest: 9.72499
# Average R2 on all folds using Random Forest: 0.58178
# Average MAPE on all folds using Random Forest: 35.62883
#
# Depth = 91
# Average RMSE on all folds using Random Forest: 9.641
# Average R2 on all folds using Random Forest: 0.59067
# Average MAPE on all folds using Random Forest: 36.00922
#
# Depth = 92
# Average RMSE on all folds using Random Forest: 9.7254
# Average R2 on all folds using Random Forest: 0.58404
# Average MAPE on all folds using Random Forest: 33.52851
#
# Depth = 93
# Average RMSE on all folds using Random Forest: 9.73282
# Average R2 on all folds using Random Forest: 0.58197
# Average MAPE on all folds using Random Forest: 33.40852
#
# Depth = 94
# Average RMSE on all folds using Random Forest: 9.58162
# Average R2 on all folds using Random Forest: 0.59624
# Average MAPE on all folds using Random Forest: 33.39697
#
# Depth = 95
# Average RMSE on all folds using Random Forest: 9.75066
# Average R2 on all folds using Random Forest: 0.57926
# Average MAPE on all folds using Random Forest: 37.99009
#
# Depth = 96
# Average RMSE on all folds using Random Forest: 9.74443
# Average R2 on all folds using Random Forest: 0.58131
# Average MAPE on all folds using Random Forest: 52.54664
#
# Depth = 97
# Average RMSE on all folds using Random Forest: 9.67309
# Average R2 on all folds using Random Forest: 0.58685
# Average MAPE on all folds using Random Forest: 80.07116
#
# Depth = 98
# Average RMSE on all folds using Random Forest: 9.64013
# Average R2 on all folds using Random Forest: 0.58949
# Average MAPE on all folds using Random Forest: 55.15509
#
# Depth = 99
# Average RMSE on all folds using Random Forest: 9.69776
# Average R2 on all folds using Random Forest: 0.58369
# Average MAPE on all folds using Random Forest: 48.92099
#
# Depth = 100
# Average RMSE on all folds using Random Forest: 9.64657
# Average R2 on all folds using Random Forest: 0.58994
# Average MAPE on all folds using Random Forest: 32.90762
#
# Depth = 101
# Average RMSE on all folds using Random Forest: 9.61801
# Average R2 on all folds using Random Forest: 0.59114
# Average MAPE on all folds using Random Forest: 53.80918
#
# Depth = 102
# Average RMSE on all folds using Random Forest: 9.71631
# Average R2 on all folds using Random Forest: 0.58349
# Average MAPE on all folds using Random Forest: 32.22001
#
# Depth = 103
# Average RMSE on all folds using Random Forest: 9.72449
# Average R2 on all folds using Random Forest: 0.58294
# Average MAPE on all folds using Random Forest: 33.98457
#
# Depth = 104
# Average RMSE on all folds using Random Forest: 9.68121
# Average R2 on all folds using Random Forest: 0.58806
# Average MAPE on all folds using Random Forest: 29.72072
#
# Depth = 105
# Average RMSE on all folds using Random Forest: 9.69955
# Average R2 on all folds using Random Forest: 0.58497
# Average MAPE on all folds using Random Forest: 39.96329
#
# Depth = 106
# Average RMSE on all folds using Random Forest: 9.67414
# Average R2 on all folds using Random Forest: 0.58767
# Average MAPE on all folds using Random Forest: 34.45266
#
# Depth = 107
# Average RMSE on all folds using Random Forest: 9.70154
# Average R2 on all folds using Random Forest: 0.58453
# Average MAPE on all folds using Random Forest: 42.68094
#
# Depth = 108
# Average RMSE on all folds using Random Forest: 9.65673
# Average R2 on all folds using Random Forest: 0.58965
# Average MAPE on all folds using Random Forest: 34.9554
#
# Depth = 109
# Average RMSE on all folds using Random Forest: 9.66311
# Average R2 on all folds using Random Forest: 0.58839
# Average MAPE on all folds using Random Forest: 31.2883
#
# Depth = 110
# Average RMSE on all folds using Random Forest: 9.6266
# Average R2 on all folds using Random Forest: 0.5916
# Average MAPE on all folds using Random Forest: 53.74924
#
# Depth = 111
# Average RMSE on all folds using Random Forest: 9.62843
# Average R2 on all folds using Random Forest: 0.59014
# Average MAPE on all folds using Random Forest: 76.58501
#
# Depth = 112
# Average RMSE on all folds using Random Forest: 9.7354
# Average R2 on all folds using Random Forest: 0.58166
# Average MAPE on all folds using Random Forest: 33.74819
#
# Depth = 113
# Average RMSE on all folds using Random Forest: 9.66278
# Average R2 on all folds using Random Forest: 0.58638
# Average MAPE on all folds using Random Forest: 75.87163
#
# Depth = 114
# Average RMSE on all folds using Random Forest: 9.6763
# Average R2 on all folds using Random Forest: 0.58623
# Average MAPE on all folds using Random Forest: 34.70925
#
# Depth = 115
# Average RMSE on all folds using Random Forest: 9.68031
# Average R2 on all folds using Random Forest: 0.58586
# Average MAPE on all folds using Random Forest: 33.65147
#
# Depth = 116
# Average RMSE on all folds using Random Forest: 9.67357
# Average R2 on all folds using Random Forest: 0.58788
# Average MAPE on all folds using Random Forest: 29.31133
#
# Depth = 117
# Average RMSE on all folds using Random Forest: 9.70457
# Average R2 on all folds using Random Forest: 0.58431
# Average MAPE on all folds using Random Forest: 34.86749
#
# Depth = 118
# Average RMSE on all folds using Random Forest: 9.73001
# Average R2 on all folds using Random Forest: 0.58242
# Average MAPE on all folds using Random Forest: 37.54209
#
# Depth = 119
# Average RMSE on all folds using Random Forest: 9.69813
# Average R2 on all folds using Random Forest: 0.5847
# Average MAPE on all folds using Random Forest: 37.27628
#
# Depth = 120
# Average RMSE on all folds using Random Forest: 9.67129
# Average R2 on all folds using Random Forest: 0.58741
# Average MAPE on all folds using Random Forest: 55.01367
#
# Depth = 121
# Average RMSE on all folds using Random Forest: 9.63008
# Average R2 on all folds using Random Forest: 0.59087
# Average MAPE on all folds using Random Forest: 78.33835
#
# Depth = 122
# Average RMSE on all folds using Random Forest: 9.74612
# Average R2 on all folds using Random Forest: 0.58205
# Average MAPE on all folds using Random Forest: 33.17715
#
# Depth = 123
# Average RMSE on all folds using Random Forest: 9.70371
# Average R2 on all folds using Random Forest: 0.58472
# Average MAPE on all folds using Random Forest: 32.29772
#
# Depth = 124
# Average RMSE on all folds using Random Forest: 9.70885
# Average R2 on all folds using Random Forest: 0.58413
# Average MAPE on all folds using Random Forest: 74.79536
#
# Depth = 125
# Average RMSE on all folds using Random Forest: 9.68397
# Average R2 on all folds using Random Forest: 0.58738
# Average MAPE on all folds using Random Forest: 31.97246
#
# Depth = 126
# Average RMSE on all folds using Random Forest: 9.68742
# Average R2 on all folds using Random Forest: 0.58554
# Average MAPE on all folds using Random Forest: 30.78019
#
# Depth = 127
# Average RMSE on all folds using Random Forest: 9.75452
# Average R2 on all folds using Random Forest: 0.58125
# Average MAPE on all folds using Random Forest: 33.80527
#
# Depth = 128
# Average RMSE on all folds using Random Forest: 9.68609
# Average R2 on all folds using Random Forest: 0.58377
# Average MAPE on all folds using Random Forest: 35.29412
#
# Depth = 129
# Average RMSE on all folds using Random Forest: 9.68436
# Average R2 on all folds using Random Forest: 0.58604
# Average MAPE on all folds using Random Forest: 31.5608
#
# Depth = 130
# Average RMSE on all folds using Random Forest: 9.7349
# Average R2 on all folds using Random Forest: 0.58289
# Average MAPE on all folds using Random Forest: 34.12507
#
# Depth = 131
# Average RMSE on all folds using Random Forest: 9.60789
# Average R2 on all folds using Random Forest: 0.59328
# Average MAPE on all folds using Random Forest: 72.34085
#
# Depth = 132
# Average RMSE on all folds using Random Forest: 9.71499
# Average R2 on all folds using Random Forest: 0.58366
# Average MAPE on all folds using Random Forest: 82.37396
#
# Depth = 133
# Average RMSE on all folds using Random Forest: 9.66812
# Average R2 on all folds using Random Forest: 0.58863
# Average MAPE on all folds using Random Forest: 32.00772
#
# Depth = 134
# Average RMSE on all folds using Random Forest: 9.67739
# Average R2 on all folds using Random Forest: 0.58727
# Average MAPE on all folds using Random Forest: 35.73393
#
# Depth = 135
# Average RMSE on all folds using Random Forest: 9.57397
# Average R2 on all folds using Random Forest: 0.59616
# Average MAPE on all folds using Random Forest: 72.78073
#
# Depth = 136
# Average RMSE on all folds using Random Forest: 9.67505
# Average R2 on all folds using Random Forest: 0.5873
# Average MAPE on all folds using Random Forest: 39.08635
#
# Depth = 137
# Average RMSE on all folds using Random Forest: 9.68342
# Average R2 on all folds using Random Forest: 0.58675
# Average MAPE on all folds using Random Forest: 35.79405
#
# Depth = 138
# Average RMSE on all folds using Random Forest: 9.6556
# Average R2 on all folds using Random Forest: 0.5901
# Average MAPE on all folds using Random Forest: 42.42833
#
# Depth = 139
# Average RMSE on all folds using Random Forest: 9.69044
# Average R2 on all folds using Random Forest: 0.58619
# Average MAPE on all folds using Random Forest: 37.23098
#
# Depth = 140
# Average RMSE on all folds using Random Forest: 9.60442
# Average R2 on all folds using Random Forest: 0.59311
# Average MAPE on all folds using Random Forest: 33.21112
#
# Depth = 141
# Average RMSE on all folds using Random Forest: 9.62789
# Average R2 on all folds using Random Forest: 0.59169
# Average MAPE on all folds using Random Forest: 48.38248
#
# Depth = 142
# Average RMSE on all folds using Random Forest: 9.71673
# Average R2 on all folds using Random Forest: 0.58343
# Average MAPE on all folds using Random Forest: 39.21884
#
# Depth = 143
# Average RMSE on all folds using Random Forest: 9.73365
# Average R2 on all folds using Random Forest: 0.58197
# Average MAPE on all folds using Random Forest: 53.01452
#
# Depth = 144
# Average RMSE on all folds using Random Forest: 9.64333
# Average R2 on all folds using Random Forest: 0.58996
# Average MAPE on all folds using Random Forest: 94.52594
#
# Depth = 145
# Average RMSE on all folds using Random Forest: 9.63195
# Average R2 on all folds using Random Forest: 0.59178
# Average MAPE on all folds using Random Forest: 36.25206
#
# Depth = 146
# Average RMSE on all folds using Random Forest: 9.67586
# Average R2 on all folds using Random Forest: 0.58748
# Average MAPE on all folds using Random Forest: 35.11426
#
# Depth = 147
# Average RMSE on all folds using Random Forest: 9.67526
# Average R2 on all folds using Random Forest: 0.5866
# Average MAPE on all folds using Random Forest: 54.21079
#
# Depth = 148
# Average RMSE on all folds using Random Forest: 9.64718
# Average R2 on all folds using Random Forest: 0.58912
# Average MAPE on all folds using Random Forest: 33.43879
#
# Depth = 149
# Average RMSE on all folds using Random Forest: 9.70736
# Average R2 on all folds using Random Forest: 0.58534
# Average MAPE on all folds using Random Forest: 31.47959
#
# Depth = 150
# Average RMSE on all folds using Random Forest: 9.66998
# Average R2 on all folds using Random Forest: 0.58834
# Average MAPE on all folds using Random Forest: 34.56563
#
# Depth = 151
# Average RMSE on all folds using Random Forest: 9.71809
# Average R2 on all folds using Random Forest: 0.58336
# Average MAPE on all folds using Random Forest: 32.34959
#
# Depth = 152
# Average RMSE on all folds using Random Forest: 9.70846
# Average R2 on all folds using Random Forest: 0.58489
# Average MAPE on all folds using Random Forest: 30.90611
#
# Depth = 153
# Average RMSE on all folds using Random Forest: 9.73861
# Average R2 on all folds using Random Forest: 0.5816
# Average MAPE on all folds using Random Forest: 37.82272
#
# Depth = 154
# Average RMSE on all folds using Random Forest: 9.68964
# Average R2 on all folds using Random Forest: 0.58422
# Average MAPE on all folds using Random Forest: 30.4726
#
# Depth = 155
# Average RMSE on all folds using Random Forest: 9.69086
# Average R2 on all folds using Random Forest: 0.58741
# Average MAPE on all folds using Random Forest: 69.83549
#
# Depth = 156
# Average RMSE on all folds using Random Forest: 9.71856
# Average R2 on all folds using Random Forest: 0.58292
# Average MAPE on all folds using Random Forest: 55.16583
#
# Depth = 157
# Average RMSE on all folds using Random Forest: 9.59386
# Average R2 on all folds using Random Forest: 0.59315
# Average MAPE on all folds using Random Forest: 75.17326
#
# Depth = 158
# Average RMSE on all folds using Random Forest: 9.69594
# Average R2 on all folds using Random Forest: 0.5851
# Average MAPE on all folds using Random Forest: 34.6001
#
# Depth = 159
# Average RMSE on all folds using Random Forest: 9.74985
# Average R2 on all folds using Random Forest: 0.58111
# Average MAPE on all folds using Random Forest: 78.41758
#
# Depth = 160
# Average RMSE on all folds using Random Forest: 9.64853
# Average R2 on all folds using Random Forest: 0.58818
# Average MAPE on all folds using Random Forest: 76.11378
#
# Depth = 161
# Average RMSE on all folds using Random Forest: 9.6723
# Average R2 on all folds using Random Forest: 0.58794
# Average MAPE on all folds using Random Forest: 76.85246
#
# Depth = 162
# Average RMSE on all folds using Random Forest: 9.62613
# Average R2 on all folds using Random Forest: 0.59114
# Average MAPE on all folds using Random Forest: 34.51023
#
# Depth = 163
# Average RMSE on all folds using Random Forest: 9.67873
# Average R2 on all folds using Random Forest: 0.58809
# Average MAPE on all folds using Random Forest: 38.13844
#
# Depth = 164
# Average RMSE on all folds using Random Forest: 9.64629
# Average R2 on all folds using Random Forest: 0.59059
# Average MAPE on all folds using Random Forest: 34.67964
#
# Depth = 165
# Average RMSE on all folds using Random Forest: 9.67145
# Average R2 on all folds using Random Forest: 0.58782
# Average MAPE on all folds using Random Forest: 38.9381
#
# Depth = 166
# Average RMSE on all folds using Random Forest: 9.64223
# Average R2 on all folds using Random Forest: 0.59099
# Average MAPE on all folds using Random Forest: 75.09931
#
# Depth = 167
# Average RMSE on all folds using Random Forest: 9.68523
# Average R2 on all folds using Random Forest: 0.58656
# Average MAPE on all folds using Random Forest: 34.24885
#
# Depth = 168
# Average RMSE on all folds using Random Forest: 9.60302
# Average R2 on all folds using Random Forest: 0.59278
# Average MAPE on all folds using Random Forest: 47.8589
#
# Depth = 169
# Average RMSE on all folds using Random Forest: 9.73438
# Average R2 on all folds using Random Forest: 0.5809
# Average MAPE on all folds using Random Forest: 36.21423
#
# Depth = 170
# Average RMSE on all folds using Random Forest: 9.65465
# Average R2 on all folds using Random Forest: 0.58879
# Average MAPE on all folds using Random Forest: 38.72757
#
# Depth = 171
# Average RMSE on all folds using Random Forest: 9.69453
# Average R2 on all folds using Random Forest: 0.58535
# Average MAPE on all folds using Random Forest: 33.48001
#
# Depth = 172
# Average RMSE on all folds using Random Forest: 9.62065
# Average R2 on all folds using Random Forest: 0.59199
# Average MAPE on all folds using Random Forest: 32.14528
#
# Depth = 173
# Average RMSE on all folds using Random Forest: 9.68749
# Average R2 on all folds using Random Forest: 0.58598
# Average MAPE on all folds using Random Forest: 36.00585
#
# Depth = 174
# Average RMSE on all folds using Random Forest: 9.62395
# Average R2 on all folds using Random Forest: 0.59116
# Average MAPE on all folds using Random Forest: 34.02746
#
# Depth = 175
# Average RMSE on all folds using Random Forest: 9.73597
# Average R2 on all folds using Random Forest: 0.58327
# Average MAPE on all folds using Random Forest: 30.89549
#
# Depth = 176
# Average RMSE on all folds using Random Forest: 9.67087
# Average R2 on all folds using Random Forest: 0.58668
# Average MAPE on all folds using Random Forest: 33.56179
#
# Depth = 177
# Average RMSE on all folds using Random Forest: 9.60367
# Average R2 on all folds using Random Forest: 0.59392
# Average MAPE on all folds using Random Forest: 39.28055
#
# Depth = 178
# Average RMSE on all folds using Random Forest: 9.75891
# Average R2 on all folds using Random Forest: 0.58014
# Average MAPE on all folds using Random Forest: 35.44568
#
# Depth = 179
# Average RMSE on all folds using Random Forest: 9.64338
# Average R2 on all folds using Random Forest: 0.59044
# Average MAPE on all folds using Random Forest: 33.23051
#
# Depth = 180
# Average RMSE on all folds using Random Forest: 9.59481
# Average R2 on all folds using Random Forest: 0.59327
# Average MAPE on all folds using Random Forest: 34.72578
#
# Depth = 181
# Average RMSE on all folds using Random Forest: 9.63525
# Average R2 on all folds using Random Forest: 0.59166
# Average MAPE on all folds using Random Forest: 37.31556
#
# Depth = 182
# Average RMSE on all folds using Random Forest: 9.6908
# Average R2 on all folds using Random Forest: 0.58603
# Average MAPE on all folds using Random Forest: 75.74641
#
# Depth = 183
# Average RMSE on all folds using Random Forest: 9.59162
# Average R2 on all folds using Random Forest: 0.59275
# Average MAPE on all folds using Random Forest: 47.29515
#
# Depth = 184
# Average RMSE on all folds using Random Forest: 9.74626
# Average R2 on all folds using Random Forest: 0.58206
# Average MAPE on all folds using Random Forest: 35.25622
#
# Depth = 185
# Average RMSE on all folds using Random Forest: 9.6755
# Average R2 on all folds using Random Forest: 0.58726
# Average MAPE on all folds using Random Forest: 50.76945
#
# Depth = 186
# Average RMSE on all folds using Random Forest: 9.66509
# Average R2 on all folds using Random Forest: 0.58877
# Average MAPE on all folds using Random Forest: 35.52715
#
# Depth = 187
# Average RMSE on all folds using Random Forest: 9.71444
# Average R2 on all folds using Random Forest: 0.58303
# Average MAPE on all folds using Random Forest: 77.18711
#
# Depth = 188
# Average RMSE on all folds using Random Forest: 9.69706
# Average R2 on all folds using Random Forest: 0.58502
# Average MAPE on all folds using Random Forest: 52.30343
#
# Depth = 189
# Average RMSE on all folds using Random Forest: 9.63363
# Average R2 on all folds using Random Forest: 0.59099
# Average MAPE on all folds using Random Forest: 33.4601
#
# Depth = 190
# Average RMSE on all folds using Random Forest: 9.66566
# Average R2 on all folds using Random Forest: 0.58859
# Average MAPE on all folds using Random Forest: 31.83267
#
# Depth = 191
# Average RMSE on all folds using Random Forest: 9.71329
# Average R2 on all folds using Random Forest: 0.58396
# Average MAPE on all folds using Random Forest: 33.59855
#
# Depth = 192
# Average RMSE on all folds using Random Forest: 9.73751
# Average R2 on all folds using Random Forest: 0.5806
# Average MAPE on all folds using Random Forest: 33.60783
#
# Depth = 193
# Average RMSE on all folds using Random Forest: 9.66148
# Average R2 on all folds using Random Forest: 0.58757
# Average MAPE on all folds using Random Forest: 35.63044
#
# Depth = 194
# Average RMSE on all folds using Random Forest: 9.66147
# Average R2 on all folds using Random Forest: 0.58773
# Average MAPE on all folds using Random Forest: 52.37108
#
# Depth = 195
# Average RMSE on all folds using Random Forest: 9.66583
# Average R2 on all folds using Random Forest: 0.58663
# Average MAPE on all folds using Random Forest: 36.79239
#
# Depth = 196
# Average RMSE on all folds using Random Forest: 9.70465
# Average R2 on all folds using Random Forest: 0.58551
# Average MAPE on all folds using Random Forest: 33.13145
#
# Depth = 197
# Average RMSE on all folds using Random Forest: 9.69811
# Average R2 on all folds using Random Forest: 0.5855
# Average MAPE on all folds using Random Forest: 34.37956
#
# Depth = 198
# Average RMSE on all folds using Random Forest: 9.61063
# Average R2 on all folds using Random Forest: 0.59187
# Average MAPE on all folds using Random Forest: 33.60858
#
# Depth = 199
# Average RMSE on all folds using Random Forest: 9.67217
# Average R2 on all folds using Random Forest: 0.58796
# Average MAPE on all folds using Random Forest: 35.59552
#
# Best depth for RMSE is 135 with RMSE = 9.57397
# Best depth for R2 is 94 with R2 = 0.59624
# Best depth for MAPE is 116 with MAPE = 29.31133
# ---------------------------------------------
#
# Data without cluster
#
# ---------------------------------------------
# (4679, 13) (4679,)
# Depth = 1
# Average RMSE on all folds using Random Forest: 13.75485
# Average R2 on all folds using Random Forest: 0.16399
# Average MAPE on all folds using Random Forest: 67.6002
#
# Depth = 2
# Average RMSE on all folds using Random Forest: 12.08198
# Average R2 on all folds using Random Forest: 0.3567
# Average MAPE on all folds using Random Forest: 43.44427
#
# Depth = 3
# Average RMSE on all folds using Random Forest: 11.22084
# Average R2 on all folds using Random Forest: 0.44621
# Average MAPE on all folds using Random Forest: 55.33853
#
# Depth = 4
# Average RMSE on all folds using Random Forest: 10.86927
# Average R2 on all folds using Random Forest: 0.47687
# Average MAPE on all folds using Random Forest: 37.68497
#
# Depth = 5
# Average RMSE on all folds using Random Forest: 10.55065
# Average R2 on all folds using Random Forest: 0.50974
# Average MAPE on all folds using Random Forest: 36.75673
#
# Depth = 6
# Average RMSE on all folds using Random Forest: 10.3941
# Average R2 on all folds using Random Forest: 0.52323
# Average MAPE on all folds using Random Forest: 60.38078
#
# Depth = 7
# Average RMSE on all folds using Random Forest: 10.20848
# Average R2 on all folds using Random Forest: 0.54177
# Average MAPE on all folds using Random Forest: 37.41235
#
# Depth = 8
# Average RMSE on all folds using Random Forest: 10.21148
# Average R2 on all folds using Random Forest: 0.53941
# Average MAPE on all folds using Random Forest: 38.01264
#
# Depth = 9
# Average RMSE on all folds using Random Forest: 10.08567
# Average R2 on all folds using Random Forest: 0.55049
# Average MAPE on all folds using Random Forest: 36.29147
#
# Depth = 10
# Average RMSE on all folds using Random Forest: 10.13248
# Average R2 on all folds using Random Forest: 0.54642
# Average MAPE on all folds using Random Forest: 39.39858
#
# Depth = 11
# Average RMSE on all folds using Random Forest: 10.12223
# Average R2 on all folds using Random Forest: 0.54923
# Average MAPE on all folds using Random Forest: 36.17274
#
# Depth = 12
# Average RMSE on all folds using Random Forest: 10.08849
# Average R2 on all folds using Random Forest: 0.55159
# Average MAPE on all folds using Random Forest: 39.7948
#
# Depth = 13
# Average RMSE on all folds using Random Forest: 10.07032
# Average R2 on all folds using Random Forest: 0.55325
# Average MAPE on all folds using Random Forest: 36.7755
#
# Depth = 14
# Average RMSE on all folds using Random Forest: 10.11882
# Average R2 on all folds using Random Forest: 0.54887
# Average MAPE on all folds using Random Forest: 34.72308
#
# Depth = 15
# Average RMSE on all folds using Random Forest: 9.92751
# Average R2 on all folds using Random Forest: 0.56458
# Average MAPE on all folds using Random Forest: 38.49104
#
# Depth = 16
# Average RMSE on all folds using Random Forest: 10.01973
# Average R2 on all folds using Random Forest: 0.55794
# Average MAPE on all folds using Random Forest: 38.22108
#
# Depth = 17
# Average RMSE on all folds using Random Forest: 9.94583
# Average R2 on all folds using Random Forest: 0.56462
# Average MAPE on all folds using Random Forest: 37.98098
#
# Depth = 18
# Average RMSE on all folds using Random Forest: 9.96891
# Average R2 on all folds using Random Forest: 0.56131
# Average MAPE on all folds using Random Forest: 37.47702
#
# Depth = 19
# Average RMSE on all folds using Random Forest: 9.8744
# Average R2 on all folds using Random Forest: 0.56908
# Average MAPE on all folds using Random Forest: 32.56077
#
# Depth = 20
# Average RMSE on all folds using Random Forest: 9.97766
# Average R2 on all folds using Random Forest: 0.5619
# Average MAPE on all folds using Random Forest: 35.38085
#
# Depth = 21
# Average RMSE on all folds using Random Forest: 9.83862
# Average R2 on all folds using Random Forest: 0.57368
# Average MAPE on all folds using Random Forest: 31.70584
#
# Depth = 22
# Average RMSE on all folds using Random Forest: 9.85173
# Average R2 on all folds using Random Forest: 0.5717
# Average MAPE on all folds using Random Forest: 35.15156
#
# Depth = 23
# Average RMSE on all folds using Random Forest: 9.86121
# Average R2 on all folds using Random Forest: 0.57151
# Average MAPE on all folds using Random Forest: 32.84686
#
# Depth = 24
# Average RMSE on all folds using Random Forest: 9.85618
# Average R2 on all folds using Random Forest: 0.57185
# Average MAPE on all folds using Random Forest: 76.00511
#
# Depth = 25
# Average RMSE on all folds using Random Forest: 9.82113
# Average R2 on all folds using Random Forest: 0.57488
# Average MAPE on all folds using Random Forest: 33.55731
#
# Depth = 26
# Average RMSE on all folds using Random Forest: 9.87161
# Average R2 on all folds using Random Forest: 0.56982
# Average MAPE on all folds using Random Forest: 77.65262
#
# Depth = 27
# Average RMSE on all folds using Random Forest: 9.83444
# Average R2 on all folds using Random Forest: 0.57247
# Average MAPE on all folds using Random Forest: 37.76776
#
# Depth = 28
# Average RMSE on all folds using Random Forest: 9.7699
# Average R2 on all folds using Random Forest: 0.57925
# Average MAPE on all folds using Random Forest: 38.82172
#
# Depth = 29
# Average RMSE on all folds using Random Forest: 9.80497
# Average R2 on all folds using Random Forest: 0.57729
# Average MAPE on all folds using Random Forest: 37.31759
#
# Depth = 30
# Average RMSE on all folds using Random Forest: 9.88473
# Average R2 on all folds using Random Forest: 0.56831
# Average MAPE on all folds using Random Forest: 88.31309
#
# Depth = 31
# Average RMSE on all folds using Random Forest: 9.77125
# Average R2 on all folds using Random Forest: 0.57618
# Average MAPE on all folds using Random Forest: 36.22624
#
# Depth = 32
# Average RMSE on all folds using Random Forest: 9.84544
# Average R2 on all folds using Random Forest: 0.57307
# Average MAPE on all folds using Random Forest: 37.70074
#
# Depth = 33
# Average RMSE on all folds using Random Forest: 9.82975
# Average R2 on all folds using Random Forest: 0.57409
# Average MAPE on all folds using Random Forest: 32.42561
#
# Depth = 34
# Average RMSE on all folds using Random Forest: 9.83874
# Average R2 on all folds using Random Forest: 0.57159
# Average MAPE on all folds using Random Forest: 38.81454
#
# Depth = 35
# Average RMSE on all folds using Random Forest: 9.8125
# Average R2 on all folds using Random Forest: 0.57632
# Average MAPE on all folds using Random Forest: 34.55082
#
# Depth = 36
# Average RMSE on all folds using Random Forest: 9.77479
# Average R2 on all folds using Random Forest: 0.57977
# Average MAPE on all folds using Random Forest: 30.36729
#
# Depth = 37
# Average RMSE on all folds using Random Forest: 9.82166
# Average R2 on all folds using Random Forest: 0.57545
# Average MAPE on all folds using Random Forest: 36.65518
#
# Depth = 38
# Average RMSE on all folds using Random Forest: 9.73348
# Average R2 on all folds using Random Forest: 0.58119
# Average MAPE on all folds using Random Forest: 36.90245
#
# Depth = 39
# Average RMSE on all folds using Random Forest: 9.72644
# Average R2 on all folds using Random Forest: 0.58381
# Average MAPE on all folds using Random Forest: 82.19242
#
# Depth = 40
# Average RMSE on all folds using Random Forest: 9.79341
# Average R2 on all folds using Random Forest: 0.57795
# Average MAPE on all folds using Random Forest: 80.93172
#
# Depth = 41
# Average RMSE on all folds using Random Forest: 9.81505
# Average R2 on all folds using Random Forest: 0.57514
# Average MAPE on all folds using Random Forest: 38.91367
#
# Depth = 42
# Average RMSE on all folds using Random Forest: 9.79244
# Average R2 on all folds using Random Forest: 0.57723
# Average MAPE on all folds using Random Forest: 39.6297
#
# Depth = 43
# Average RMSE on all folds using Random Forest: 9.75975
# Average R2 on all folds using Random Forest: 0.58043
# Average MAPE on all folds using Random Forest: 34.88544
#
# Depth = 44
# Average RMSE on all folds using Random Forest: 9.792
# Average R2 on all folds using Random Forest: 0.57758
# Average MAPE on all folds using Random Forest: 79.128
#
# Depth = 45
# Average RMSE on all folds using Random Forest: 9.73523
# Average R2 on all folds using Random Forest: 0.58208
# Average MAPE on all folds using Random Forest: 32.30261
#
# Depth = 46
# Average RMSE on all folds using Random Forest: 9.80861
# Average R2 on all folds using Random Forest: 0.57578
# Average MAPE on all folds using Random Forest: 32.49562
#
# Depth = 47
# Average RMSE on all folds using Random Forest: 9.74674
# Average R2 on all folds using Random Forest: 0.58102
# Average MAPE on all folds using Random Forest: 49.65719
#
# Depth = 48
# Average RMSE on all folds using Random Forest: 9.76428
# Average R2 on all folds using Random Forest: 0.57913
# Average MAPE on all folds using Random Forest: 34.49203
#
# Depth = 49
# Average RMSE on all folds using Random Forest: 9.8124
# Average R2 on all folds using Random Forest: 0.57595
# Average MAPE on all folds using Random Forest: 51.85382
#
# Depth = 50
# Average RMSE on all folds using Random Forest: 9.74429
# Average R2 on all folds using Random Forest: 0.5816
# Average MAPE on all folds using Random Forest: 50.80384
#
# Depth = 51
# Average RMSE on all folds using Random Forest: 9.78815
# Average R2 on all folds using Random Forest: 0.57785
# Average MAPE on all folds using Random Forest: 76.32999
#
# Depth = 52
# Average RMSE on all folds using Random Forest: 9.72604
# Average R2 on all folds using Random Forest: 0.58284
# Average MAPE on all folds using Random Forest: 40.06599
#
# Depth = 53
# Average RMSE on all folds using Random Forest: 9.7705
# Average R2 on all folds using Random Forest: 0.5795
# Average MAPE on all folds using Random Forest: 36.01585
#
# Depth = 54
# Average RMSE on all folds using Random Forest: 9.74006
# Average R2 on all folds using Random Forest: 0.58192
# Average MAPE on all folds using Random Forest: 36.95354
#
# Depth = 55
# Average RMSE on all folds using Random Forest: 9.72097
# Average R2 on all folds using Random Forest: 0.58229
# Average MAPE on all folds using Random Forest: 97.74831
#
# Depth = 56
# Average RMSE on all folds using Random Forest: 9.68079
# Average R2 on all folds using Random Forest: 0.58629
# Average MAPE on all folds using Random Forest: 36.72602
#
# Depth = 57
# Average RMSE on all folds using Random Forest: 9.75367
# Average R2 on all folds using Random Forest: 0.58035
# Average MAPE on all folds using Random Forest: 34.72057
#
# Depth = 58
# Average RMSE on all folds using Random Forest: 9.78603
# Average R2 on all folds using Random Forest: 0.57629
# Average MAPE on all folds using Random Forest: 34.69512
#
# Depth = 59
# Average RMSE on all folds using Random Forest: 9.76353
# Average R2 on all folds using Random Forest: 0.5806
# Average MAPE on all folds using Random Forest: 91.63927
#
# Depth = 60
# Average RMSE on all folds using Random Forest: 9.73124
# Average R2 on all folds using Random Forest: 0.58277
# Average MAPE on all folds using Random Forest: 38.39655
#
# Depth = 61
# Average RMSE on all folds using Random Forest: 9.74018
# Average R2 on all folds using Random Forest: 0.58202
# Average MAPE on all folds using Random Forest: 35.39711
#
# Depth = 62
# Average RMSE on all folds using Random Forest: 9.79269
# Average R2 on all folds using Random Forest: 0.57686
# Average MAPE on all folds using Random Forest: 34.87644
#
# Depth = 63
# Average RMSE on all folds using Random Forest: 9.83596
# Average R2 on all folds using Random Forest: 0.57137
# Average MAPE on all folds using Random Forest: 35.70145
#
# Depth = 64
# Average RMSE on all folds using Random Forest: 9.73795
# Average R2 on all folds using Random Forest: 0.581
# Average MAPE on all folds using Random Forest: 33.49967
#
# Depth = 65
# Average RMSE on all folds using Random Forest: 9.73659
# Average R2 on all folds using Random Forest: 0.5809
# Average MAPE on all folds using Random Forest: 32.20358
#
# Depth = 66
# Average RMSE on all folds using Random Forest: 9.71834
# Average R2 on all folds using Random Forest: 0.58383
# Average MAPE on all folds using Random Forest: 35.5912
#
# Depth = 67
# Average RMSE on all folds using Random Forest: 9.70572
# Average R2 on all folds using Random Forest: 0.58355
# Average MAPE on all folds using Random Forest: 34.90735
#
# Depth = 68
# Average RMSE on all folds using Random Forest: 9.71223
# Average R2 on all folds using Random Forest: 0.58428
# Average MAPE on all folds using Random Forest: 36.82944
#
# Depth = 69
# Average RMSE on all folds using Random Forest: 9.81302
# Average R2 on all folds using Random Forest: 0.57607
# Average MAPE on all folds using Random Forest: 39.92335
#
# Depth = 70
# Average RMSE on all folds using Random Forest: 9.69848
# Average R2 on all folds using Random Forest: 0.58449
# Average MAPE on all folds using Random Forest: 36.00573
#
# Depth = 71
# Average RMSE on all folds using Random Forest: 9.73121
# Average R2 on all folds using Random Forest: 0.58157
# Average MAPE on all folds using Random Forest: 31.91742
#
# Depth = 72
# ...
# Average R2 on all folds using Random Forest: 0.5871
# Average MAPE on all folds using Random Forest: 33.69398
#
# Depth = 111
# Average RMSE on all folds using Random Forest: 9.63348
# Average R2 on all folds using Random Forest: 0.59001
# Average MAPE on all folds using Random Forest: 48.9657
#
# Depth = 112
# Average RMSE on all folds using Random Forest: 9.69032
# Average R2 on all folds using Random Forest: 0.58663
# Average MAPE on all folds using Random Forest: 41.71966
#
# Depth = 113
# Average RMSE on all folds using Random Forest: 9.68985
# Average R2 on all folds using Random Forest: 0.58548
# Average MAPE on all folds using Random Forest: 84.08659
#
# Depth = 114
# Average RMSE on all folds using Random Forest: 9.71553
# Average R2 on all folds using Random Forest: 0.58299
# Average MAPE on all folds using Random Forest: 27.3513
#
# Depth = 115
# Average RMSE on all folds using Random Forest: 9.66447
# Average R2 on all folds using Random Forest: 0.58929
# Average MAPE on all folds using Random Forest: 31.08156
#
# Depth = 116
# Average RMSE on all folds using Random Forest: 9.72284
# Average R2 on all folds using Random Forest: 0.58325
# Average MAPE on all folds using Random Forest: 38.90791
#
# Depth = 117
# Average RMSE on all folds using Random Forest: 9.65487
# Average R2 on all folds using Random Forest: 0.58937
# Average MAPE on all folds using Random Forest: 32.68374
#
# Depth = 118
# Average RMSE on all folds using Random Forest: 9.68872
# Average R2 on all folds using Random Forest: 0.58637
# Average MAPE on all folds using Random Forest: 73.42878
#
# Depth = 119
# Average RMSE on all folds using Random Forest: 9.68637
# Average R2 on all folds using Random Forest: 0.5862
# Average MAPE on all folds using Random Forest: 28.59624
#
# Depth = 120
# Average RMSE on all folds using Random Forest: 9.68568
# Average R2 on all folds using Random Forest: 0.58728
# Average MAPE on all folds using Random Forest: 30.70461
#
# Depth = 121
# Average RMSE on all folds using Random Forest: 9.67837
# Average R2 on all folds using Random Forest: 0.58734
# Average MAPE on all folds using Random Forest: 36.24606
#
# Depth = 122
# Average RMSE on all folds using Random Forest: 9.70477
# Average R2 on all folds using Random Forest: 0.58263
# Average MAPE on all folds using Random Forest: 30.08978
#
# Depth = 123
# Average RMSE on all folds using Random Forest: 9.71622
# Average R2 on all folds using Random Forest: 0.58425
# Average MAPE on all folds using Random Forest: 34.54103
#
# Depth = 124
# Average RMSE on all folds using Random Forest: 9.63579
# Average R2 on all folds using Random Forest: 0.59083
# Average MAPE on all folds using Random Forest: 73.72955
#
# Depth = 125
# Average RMSE on all folds using Random Forest: 9.65115
# Average R2 on all folds using Random Forest: 0.58912
# Average MAPE on all folds using Random Forest: 31.49088
#
# Depth = 126
# Average RMSE on all folds using Random Forest: 9.68583
# Average R2 on all folds using Random Forest: 0.58664
# Average MAPE on all folds using Random Forest: 33.79345
#
# Depth = 127
# Average RMSE on all folds using Random Forest: 9.68132
# Average R2 on all folds using Random Forest: 0.58763
# Average MAPE on all folds using Random Forest: 34.23925
#
# Depth = 128
# Average RMSE on all folds using Random Forest: 9.65833
# Average R2 on all folds using Random Forest: 0.58851
# Average MAPE on all folds using Random Forest: 51.42159
#
# Depth = 129
# Average RMSE on all folds using Random Forest: 9.73267
# Average R2 on all folds using Random Forest: 0.58056
# Average MAPE on all folds using Random Forest: 74.02655
#
# Depth = 130
# Average RMSE on all folds using Random Forest: 9.72003
# Average R2 on all folds using Random Forest: 0.58177
# Average MAPE on all folds using Random Forest: 34.60305
#
# Depth = 131
# Average RMSE on all folds using Random Forest: 9.71721
# Average R2 on all folds using Random Forest: 0.58423
# Average MAPE on all folds using Random Forest: 47.61468
#
# Depth = 132
# Average RMSE on all folds using Random Forest: 9.7412
# Average R2 on all folds using Random Forest: 0.58191
# Average MAPE on all folds using Random Forest: 48.52388
#
# Depth = 133
# Average RMSE on all folds using Random Forest: 9.66265
# Average R2 on all folds using Random Forest: 0.58871
# Average MAPE on all folds using Random Forest: 32.32598
#
# Depth = 134
# Average RMSE on all folds using Random Forest: 9.68536
# Average R2 on all folds using Random Forest: 0.58637
# Average MAPE on all folds using Random Forest: 97.42658
#
# Depth = 135
# Average RMSE on all folds using Random Forest: 9.6656
# Average R2 on all folds using Random Forest: 0.5878
# Average MAPE on all folds using Random Forest: 41.48438
#
# Depth = 136
# Average RMSE on all folds using Random Forest: 9.74409
# Average R2 on all folds using Random Forest: 0.58221
# Average MAPE on all folds using Random Forest: 30.73466
#
# Depth = 137
# Average RMSE on all folds using Random Forest: 9.68472
# Average R2 on all folds using Random Forest: 0.58756
# Average MAPE on all folds using Random Forest: 50.05903
#
# Depth = 138
# Average RMSE on all folds using Random Forest: 9.72691
# Average R2 on all folds using Random Forest: 0.58367
# Average MAPE on all folds using Random Forest: 35.62135
#
# Depth = 139
# Average RMSE on all folds using Random Forest: 9.70583
# Average R2 on all folds using Random Forest: 0.58458
# Average MAPE on all folds using Random Forest: 33.14673
#
# Depth = 140
# Average RMSE on all folds using Random Forest: 9.80802
# Average R2 on all folds using Random Forest: 0.57566
# Average MAPE on all folds using Random Forest: 32.5521
#
# Depth = 141
# Average RMSE on all folds using Random Forest: 9.67956
# Average R2 on all folds using Random Forest: 0.58539
# Average MAPE on all folds using Random Forest: 32.1941
#
# Depth = 142
# Average RMSE on all folds using Random Forest: 9.72231
# Average R2 on all folds using Random Forest: 0.58259
# Average MAPE on all folds using Random Forest: 33.09546
#
# Depth = 143
# Average RMSE on all folds using Random Forest: 9.67845
# Average R2 on all folds using Random Forest: 0.58495
# Average MAPE on all folds using Random Forest: 37.88424
#
# Depth = 144
# Average RMSE on all folds using Random Forest: 9.69171
# Average R2 on all folds using Random Forest: 0.58432
# Average MAPE on all folds using Random Forest: 38.39982
#
# Depth = 145
# Average RMSE on all folds using Random Forest: 9.68988
# Average R2 on all folds using Random Forest: 0.58702
# Average MAPE on all folds using Random Forest: 33.10309
#
# Depth = 146
# Average RMSE on all folds using Random Forest: 9.6295
# Average R2 on all folds using Random Forest: 0.59039
# Average MAPE on all folds using Random Forest: 30.7052
#
# Depth = 147
# Average RMSE on all folds using Random Forest: 9.68272
# Average R2 on all folds using Random Forest: 0.58802
# Average MAPE on all folds using Random Forest: 34.50295
#
# Depth = 148
# Average RMSE on all folds using Random Forest: 9.73871
# Average R2 on all folds using Random Forest: 0.5818
# Average MAPE on all folds using Random Forest: 37.45498
#
# Depth = 149
# Average RMSE on all folds using Random Forest: 9.69454
# Average R2 on all folds using Random Forest: 0.58654
# Average MAPE on all folds using Random Forest: 56.53746
#
# Depth = 150
# Average RMSE on all folds using Random Forest: 9.75874
# Average R2 on all folds using Random Forest: 0.58013
# Average MAPE on all folds using Random Forest: 38.70039
#
# Depth = 151
# Average RMSE on all folds using Random Forest: 9.7316
# Average R2 on all folds using Random Forest: 0.58213
# Average MAPE on all folds using Random Forest: 36.28322
#
# Depth = 152
# Average RMSE on all folds using Random Forest: 9.68681
# Average R2 on all folds using Random Forest: 0.58544
# Average MAPE on all folds using Random Forest: 74.90919
#
# Depth = 153
# Average RMSE on all folds using Random Forest: 9.71848
# Average R2 on all folds using Random Forest: 0.58211
# Average MAPE on all folds using Random Forest: 35.91471
#
# Depth = 154
# Average RMSE on all folds using Random Forest: 9.7194
# Average R2 on all folds using Random Forest: 0.58343
# Average MAPE on all folds using Random Forest: 33.28665
#
# Depth = 155
# Average RMSE on all folds using Random Forest: 9.73337
# Average R2 on all folds using Random Forest: 0.58208
# Average MAPE on all folds using Random Forest: 33.55842
#
# Depth = 156
# Average RMSE on all folds using Random Forest: 9.70856
# Average R2 on all folds using Random Forest: 0.58344
# Average MAPE on all folds using Random Forest: 78.58503
#
# Depth = 157
# Average RMSE on all folds using Random Forest: 9.66775
# Average R2 on all folds using Random Forest: 0.58844
# Average MAPE on all folds using Random Forest: 34.61342
#
# Depth = 158
# Average RMSE on all folds using Random Forest: 9.73939
# Average R2 on all folds using Random Forest: 0.58107
# Average MAPE on all folds using Random Forest: 32.86259
#
# Depth = 159
# Average RMSE on all folds using Random Forest: 9.69958
# Average R2 on all folds using Random Forest: 0.58572
# Average MAPE on all folds using Random Forest: 54.35054
#
# Depth = 160
# Average RMSE on all folds using Random Forest: 9.78886
# Average R2 on all folds using Random Forest: 0.57731
# Average MAPE on all folds using Random Forest: 37.29008
#
# Depth = 161
# Average RMSE on all folds using Random Forest: 9.72267
# Average R2 on all folds using Random Forest: 0.58315
# Average MAPE on all folds using Random Forest: 31.92294
#
# Depth = 162
# Average RMSE on all folds using Random Forest: 9.68139
# Average R2 on all folds using Random Forest: 0.5858
# Average MAPE on all folds using Random Forest: 31.62726
#
# Depth = 163
# Average RMSE on all folds using Random Forest: 9.62055
# Average R2 on all folds using Random Forest: 0.59207
# Average MAPE on all folds using Random Forest: 36.37535
#
# Depth = 164
# Average RMSE on all folds using Random Forest: 9.73937
# Average R2 on all folds using Random Forest: 0.58196
# Average MAPE on all folds using Random Forest: 44.59413
#
# Depth = 165
# Average RMSE on all folds using Random Forest: 9.72307
# Average R2 on all folds using Random Forest: 0.58352
# Average MAPE on all folds using Random Forest: 34.95287
#
# Depth = 166
# Average RMSE on all folds using Random Forest: 9.61365
# Average R2 on all folds using Random Forest: 0.59333
# Average MAPE on all folds using Random Forest: 78.12995
#
# Depth = 167
# Average RMSE on all folds using Random Forest: 9.69463
# Average R2 on all folds using Random Forest: 0.58631
# Average MAPE on all folds using Random Forest: 34.32131
#
# Depth = 168
# Average RMSE on all folds using Random Forest: 9.72018
# Average R2 on all folds using Random Forest: 0.58467
# Average MAPE on all folds using Random Forest: 36.64022
#
# Depth = 169
# Average RMSE on all folds using Random Forest: 9.75423
# Average R2 on all folds using Random Forest: 0.58176
# Average MAPE on all folds using Random Forest: 42.30198
#
# Depth = 170
# Average RMSE on all folds using Random Forest: 9.70847
# Average R2 on all folds using Random Forest: 0.58429
# Average MAPE on all folds using Random Forest: 33.122
#
# Depth = 171
# Average RMSE on all folds using Random Forest: 9.66591
# Average R2 on all folds using Random Forest: 0.58933
# Average MAPE on all folds using Random Forest: 34.03567
#
# Depth = 172
# Average RMSE on all folds using Random Forest: 9.69411
# Average R2 on all folds using Random Forest: 0.58595
# Average MAPE on all folds using Random Forest: 37.7409
#
# Depth = 173
# Average RMSE on all folds using Random Forest: 9.69815
# Average R2 on all folds using Random Forest: 0.58517
# Average MAPE on all folds using Random Forest: 30.93394
#
# Depth = 174
# Average RMSE on all folds using Random Forest: 9.67726
# Average R2 on all folds using Random Forest: 0.587
# Average MAPE on all folds using Random Forest: 50.88252
#
# Depth = 175
# Average RMSE on all folds using Random Forest: 9.69931
# Average R2 on all folds using Random Forest: 0.58543
# Average MAPE on all folds using Random Forest: 39.14006
#
# Depth = 176
# Average RMSE on all folds using Random Forest: 9.712
# Average R2 on all folds using Random Forest: 0.58401
# Average MAPE on all folds using Random Forest: 80.18149
#
# Depth = 177
# Average RMSE on all folds using Random Forest: 9.66046
# Average R2 on all folds using Random Forest: 0.58918
# Average MAPE on all folds using Random Forest: 38.82213
#
# Depth = 178
# Average RMSE on all folds using Random Forest: 9.68612
# Average R2 on all folds using Random Forest: 0.58696
# Average MAPE on all folds using Random Forest: 29.64364
#
# Depth = 179
# Average RMSE on all folds using Random Forest: 9.72744
# Average R2 on all folds using Random Forest: 0.58176
# Average MAPE on all folds using Random Forest: 32.48277
#
# Depth = 180
# Average RMSE on all folds using Random Forest: 9.61399
# Average R2 on all folds using Random Forest: 0.59229
# Average MAPE on all folds using Random Forest: 48.27273
#
# Depth = 181
# Average RMSE on all folds using Random Forest: 9.75445
# Average R2 on all folds using Random Forest: 0.57949
# Average MAPE on all folds using Random Forest: 31.27159
#
# Depth = 182
# Average RMSE on all folds using Random Forest: 9.72792
# Average R2 on all folds using Random Forest: 0.583
# Average MAPE on all folds using Random Forest: 33.6145
#
# Depth = 183
# Average RMSE on all folds using Random Forest: 9.63249
# Average R2 on all folds using Random Forest: 0.59121
# Average MAPE on all folds using Random Forest: 31.34398
#
# Depth = 184
# Average RMSE on all folds using Random Forest: 9.67059
# Average R2 on all folds using Random Forest: 0.58734
# Average MAPE on all folds using Random Forest: 70.45162
#
# Depth = 185
# Average RMSE on all folds using Random Forest: 9.72359
# Average R2 on all folds using Random Forest: 0.58162
# Average MAPE on all folds using Random Forest: 35.75714
#
# Depth = 186
# Average RMSE on all folds using Random Forest: 9.70981
# Average R2 on all folds using Random Forest: 0.5835
# Average MAPE on all folds using Random Forest: 38.26321
#
# Depth = 187
# Average RMSE on all folds using Random Forest: 9.71141
# Average R2 on all folds using Random Forest: 0.58456
# Average MAPE on all folds using Random Forest: 31.22558
#
# Depth = 188
# Average RMSE on all folds using Random Forest: 9.70826
# Average R2 on all folds using Random Forest: 0.58345
# Average MAPE on all folds using Random Forest: 39.8795
#
# Depth = 189
# Average RMSE on all folds using Random Forest: 9.64142
# Average R2 on all folds using Random Forest: 0.59042
# Average MAPE on all folds using Random Forest: 29.76575
#
# Depth = 190
# Average RMSE on all folds using Random Forest: 9.6438
# Average R2 on all folds using Random Forest: 0.58962
# Average MAPE on all folds using Random Forest: 32.9955
#
# Depth = 191
# Average RMSE on all folds using Random Forest: 9.67933
# Average R2 on all folds using Random Forest: 0.58763
# Average MAPE on all folds using Random Forest: 33.56221
#
# Depth = 192
# Average RMSE on all folds using Random Forest: 9.63272
# Average R2 on all folds using Random Forest: 0.59059
# Average MAPE on all folds using Random Forest: 36.07546
#
# Depth = 193
# Average RMSE on all folds using Random Forest: 9.75751
# Average R2 on all folds using Random Forest: 0.58061
# Average MAPE on all folds using Random Forest: 34.95317
#
# Depth = 194
# Average RMSE on all folds using Random Forest: 9.69501
# Average R2 on all folds using Random Forest: 0.58486
# Average MAPE on all folds using Random Forest: 34.40885
#
# Depth = 195
# Average RMSE on all folds using Random Forest: 9.73052
# Average R2 on all folds using Random Forest: 0.57984
# Average MAPE on all folds using Random Forest: 34.13252
#
# Depth = 196
# Average RMSE on all folds using Random Forest: 9.74359
# Average R2 on all folds using Random Forest: 0.58179
# Average MAPE on all folds using Random Forest: 35.39591
#
# Depth = 197
# Average RMSE on all folds using Random Forest: 9.68498
# Average R2 on all folds using Random Forest: 0.58562
# Average MAPE on all folds using Random Forest: 36.87455
#
# Depth = 198
# Average RMSE on all folds using Random Forest: 9.66274
# Average R2 on all folds using Random Forest: 0.58844
# Average MAPE on all folds using Random Forest: 55.50588
#
# Depth = 199
# Average RMSE on all folds using Random Forest: 9.67816
# Average R2 on all folds using Random Forest: 0.58645
# Average MAPE on all folds using Random Forest: 40.27488
#
# Best depth for RMSE is 166 with RMSE = 9.61365
# Best depth for R2 is 166 with R2 = 0.59333
# Best depth for MAPE is 114 with MAPE = 27.3513
