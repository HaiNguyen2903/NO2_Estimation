# %%
import pandas as pd
import numpy as np
from PIL import Image

from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

import ogr, gdal, osr, os
import numpy as np
import itertools
from math import sqrt,ceil
from sklearn.preprocessing import Normalizer

import matplotlib.pyplot as plt
import seaborn as sns

import altair as alt
from vega_datasets import data

# %%
# Mouting with google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/Shareddrives/Giang/CVDHD Final/data_to_predict_and_draw/predict_have_feature.csv")
data.loc[(data['pblh']<0) | (data['tmp']<0) | (data['pplt_dens']<0) , ['predict_rf','predict_lr']] = 0
# data[data['predict_rf']>0]
im1 = data['predict_rf'].to_numpy().reshape(768,468)
im2 = data['predict_lr'].to_numpy().reshape(768,468)

# %%
top = cm.get_cmap('Oranges_r', 128)
bottom = cm.get_cmap('Blues', 128)

newcolors = np.vstack((top(np.linspace(0, 1, 128)),
                       bottom(np.linspace(0, 1, 128))))
newcmp = ListedColormap(newcolors, name='OrangeBlue')

print("Random Forest:")
plt.figure(figsize=(10,10))
plt.imshow(im1, cmap='jet', interpolation='nearest')
plt.show()

print()

print("Linear Regression:")
plt.figure(figsize=(10,10))
plt.imshow(im2, cmap='jet', interpolation='nearest')
plt.show()
# Out:
# Random Forest:
# Linear Regression:
